# %% [markdown]
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# <p style="background-color:romance; color:plum; font-size:150%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1; font-weight:bold;">WAY TO REINVENT YOURSELF</p>
#
# <p style="background-color:romance; color:jaguar; font-size:250%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;"><strong>Data Analysis & Visualization with Python</strong></p>
#
# ![image.png](https://i.ibb.co/mT1GG7j/US-citizen.jpg)
#
# <p style="background-color:romance; color:jaguar; font-size:200%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;"><strong>Analysis of US Citizens by Income Levels</strong></p>
#
# <!-- <p style="background-color:romance; color:jaguar; font-size:200%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.1;">Project Solution</p> -->

# %% [markdown]
# <a id="content"></a>
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;">Content</p>
#
# * [Introduction](#0)
# * [About Dataset](#1)
# * [Importing Related Libraries](#2)
# * [Recognizing & Understanding Data](#3)
# * [Univariate & Multivariate Analysis](#4)
# * [Other Specific Analysis Questions](#5)
# * [Dropping Similar & Unneccessary Features](#6)
# * [Handling with Missing Values](#7)
# * [Handling with Outliers](#8)
# * [Final Step to make ready dataset for ML Models](#9)
# * [The End of the Project](#10)

# %% [markdown]
# <a id="0"></a>
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;">Introduction</p>
#
# <a href="#content" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# One of the most important components to any data science experiment that doesn’t get as much importance as it should is **``Exploratory Data Analysis (EDA)``**. In short, EDA is **``"A first look at the data"``**. It is a critical step in analyzing the data from an experiment. It is used to understand and summarize the content of the dataset to ensure that the features which we feed to our machine learning algorithms are refined and we get valid, correctly interpreted results.
# In general, looking at a column of numbers or a whole spreadsheet and determining the important characteristics of the data can be very tedious and boring. Moreover, it is **good practice to understand the problem statement** and the data before you get your hands dirty, which in view, **helps to gain a lot of insights**. I will try to explain the concept using the Adult dataset/Census Income dataset available on the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Adult). The problem statement here is to predict whether the income exceeds 50k a year or not based on the census data.
#
# **Aim of the Project**
#
# Applying Exploratory Data Analysis (EDA) and preparing the data to implement the Machine Learning Algorithms;
# 1. Analyzing the characteristics of individuals according to income groups
# 2. Preparing data to create a model that will predict the income levels of people according to their characteristics (So the "salary" feature is the target feature)

# %% [markdown]
# <a id="1"></a>
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;">About Dataset</p>
#
# <a href="https://www.kaggle.com/code/jieyima/income-classification-model/notebook" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:blue; background-color:#dfa8e4" data-toggle="popover">Kaggle: Income Classification Model</a>
#
# The Census Income dataset has 48,842 entries. Each entry contains the following information about an individual:
#
# - **salary (target feature/label):** whether or not an individual makes more than $50,000 annually. (<= 50K, >50K)
# - **age:** the age of an individual. (Integer greater than 0)
# - **workclass:** a general term to represent the employment status of an individual. (Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked)
# - **fnlwgt:** this is the number of people the census believes the entry represents. People with similar demographic characteristics should have similar weights.  There is one important caveat to remember about this statement. That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.(Integer greater than 0)
# - **education:** the highest level of education achieved by an individual. (Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.)
# - **education-num:** the highest level of education achieved in numerical form. (Integer greater than 0)
# - **marital-status:** marital status of an individual. Married-civ-spouse corresponds to a civilian spouse while Married-AF-spouse is a spouse in the Armed Forces. Married-spouse-absent includes married people living apart because either the husband or wife was employed and living at a considerable distance from home (Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse)
# - **occupation:** the general type of occupation of an individual. (Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces)
# - **relationship:** represents what this individual is relative to others. For example an individual could be a Husband. Each entry only has one relationship attribute. (Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried)
# - **race:** Descriptions of an individual’s race. (White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black)
# - **sex:** the biological sex of the individual. (Male, female)
# - **capital-gain:** capital gains for an individual. (Integer greater than or equal to 0)
# - **capital-loss:** capital loss for an individual. (Integer greater than or equal to 0)
# - **hours-per-week:** the hours an individual has reported to work per week. (continuous)
# - **native-country:** country of origin for an individual (United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands)

# %% [markdown]
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;">How to Installing/Enabling Intellisense or Autocomplete in Jupyter Notebook</p>
#
# **Installing [jupyter_contrib_nbextensions](https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/install.html)**
#
# **To install the current version from The Python Package Index (PyPI), which is a repository of software for the Python programming language, simply type:**
#
# !pip install jupyter_contrib_nbextensions
#
# **Alternatively, you can install directly from the current master branch of the repository:**
#
# !pip install https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
#
# **Enabling [Intellisense or Autocomplete in Jupyter Notebook](https://botbark.com/2019/12/18/how-to-enable-intellisense-or-autocomplete-in-jupyter-notebook/)**
#
#
# **Installing hinterland for jupyter without anaconda**
#
# **``STEP 1:``** ``Open cmd prompt and run the following commands``
#  1) pip install jupyter_contrib_nbextensions<br>
#  2) pip install jupyter_nbextensions_configurator<br>
#  3) jupyter contrib nbextension install --user<br>
#  4) jupyter nbextensions_configurator enable --user<br>
#
# **``STEP 2:``** ``Open jupyter notebook``
#  - click on nbextensions tab<br>
#  - unckeck disable configuration for nbextensions without explicit compatibility<br>
#  - put a check on Hinterland<br>
#
# **``Step 3:``** ``Open new python file and check autocomplete feature``
#
# [VIDEO SOURCE](https://www.youtube.com/watch?v=DKE8hED0fow)
#
# ![Image_Assignment](https://i.ibb.co/RbmDmD6/E8-EED4-F3-B3-F4-4571-B6-A0-1-B3224-AAB060-4-5005-c.jpg)

# %% [markdown]
# <a id="2"></a>
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;">Importing Related Libraries</p>
#
# <a href="#content" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# - Once you've Installed NumPy and Pandas etc. you can Import them as a Library.
# - Reading the Data from File

# %%
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Statistics functions
from scipy import stats

import warnings
# Suppressing a warning 
warnings.filterwarnings("ignore") 
warnings.warn("this will not show")

# The style parameters control properties like the color of the background and whether a grid is enabled by default.
sns.set_style("whitegrid")

params = {
'figure.figsize':(10,6),
'figure.titlesize':18,
'font.size': 13,
'axes.titlesize': 14,
'axes.labelsize': 12,
'xtick.labelsize': 11,
'ytick.labelsize': 11,
'legend.fontsize': 12,
'boxplot.showmeans': True,
'boxplot.meanprops.marker': 'o',
'boxplot.meanprops.markeredgecolor': 'k',
'boxplot.meanprops.markerfacecolor': 'w',
'boxplot.meanprops.markersize': 10.1,
}
# print(plt.style.library)
plt.rcParams.update(params)
# plt.rcParams.update(plt.rcParamsDefault)
# print(plt.rcParams['figure.figsize'])

# Environment settings: 
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# Set it None to display all rows in the dataframe
pd.set_option('display.max_rows', 100)
# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# It is a magic function that renders the figure in the notebook
# Attention if U use this inline Command not work 'figure.figsize'
# %matplotlib inline

# %%
sns.set(font_scale=0.8)

# %% [markdown]
# ## Reading the Data from File

# %%
df0 = pd.read_csv("adult_eda.csv")
df= df0.copy()
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors         13.000
# 1       50  Self-emp-not-inc   83311   Bachelors         13.000
# 2       38           Private  215646     HS-grad          9.000
# 3       53           Private  234721        11th          7.000
# 4       28           Private  338409   Bachelors         13.000
# ...    ...               ...     ...         ...            ...
# 32532   27           Private  257302  Assoc-acdm         12.000
# 32533   40           Private  154374     HS-grad          9.000
# 32534   58           Private  151910     HS-grad          9.000
# 32535   22           Private  201490     HS-grad          9.000
# 32536   52      Self-emp-inc  287927     HS-grad          9.000
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32532  Married-civ-spouse       Tech-support           Wife  White  Female
# 32533  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32534             Widowed       Adm-clerical      Unmarried  White  Female
# 32535       Never-married       Adm-clerical            NaN  White    Male
# 32536  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32532             0             0              38  United-States  <=50K
# 32533             0             0              40  United-States   >50K
# 32534             0             0              40  United-States  <=50K
# 32535             0             0              20  United-States  <=50K
# 32536         15024             0              40  United-States   >50K
#
# [32537 rows x 15 columns]

# %% [markdown]
# <a id="3"></a>
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;">Recognizing and Understanding Data</p>
#
# <a href="#content" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## Try to understand what the data looks like
# - Check the head, shape, data-types of the features.
# - Check if there are some dublicate rows or not. If there are, then drop them.
# - Check the statistical values of features.
# - Basically check the missing values. (NaN, None)
# - If needed, rename the columns' names for easy use.

# %% [markdown]
# ### Check the head, shape, data-types of the features.

# %%
# Your Code is Here
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/qFn8RZs/US-Citicens1.png)

# %%
# Your Code is Here
df.shape
# Out:
# (32537, 15)

# %% [raw]
# Desired Output:
#
# (32561, 15)

# %%
# Your Code is Here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32537 entries, 0 to 32536
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32537 non-null  int64
#  1   workclass       32537 non-null  object
#  2   fnlwgt          32537 non-null  int64
#  3   education       32537 non-null  object
#  4   education-num   31735 non-null  float64
#  5   marital-status  32537 non-null  object
#  6   occupation      32537 non-null  object
#  7   relationship    27473 non-null  object
#  8   race            32537 non-null  object
#  9   sex             32537 non-null  object
#  10  capital-gain    32537 non-null  int64
#  11  capital-loss    32537 non-null  int64
#  12  hours-per-week  32537 non-null  int64
#  13  native-country  32537 non-null  object
#  14  salary          32537 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %% [raw]
# Desired Output:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# ### Check if there are some dublicate rows or not. If there are, then drop them.

# %%
# Check if the Dataset have any Duplicate
duplicate_counts = df.duplicated().value_counts()
duplicate_counts
# Out:
# False    32537
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# False    32537
# True        24
# dtype: int64

# %%
# Drop Duplicates
df.drop_duplicates(inplace=True)
# Your Code is Here
df.to_csv('adult_eda.csv', index=False)
duplicate_counts = df.duplicated().value_counts()
duplicate_counts
# Out:
# False    32537
# Name: count, dtype: int64

# %%
# Check the shape of the Dataset
df.shape
# Your Code is Here
# Out:
# (32537, 15)

# %% [raw]
# Desired Output:
#
# (32537, 15)

# %% [markdown]
# ### Check the statistical values of features.

# %%
# Your Code is Here

df.describe().T
# Out:
#                    count       mean        std       min        25%  \
# age            32537.000     38.586     13.638    17.000     28.000
# fnlwgt         32537.000 189780.849 105556.471 12285.000 117827.000
# education-num  31735.000     10.084      2.575     1.000      9.000
# capital-gain   32537.000   1078.444   7387.957     0.000      0.000
# capital-loss   32537.000     87.368    403.102     0.000      0.000
# hours-per-week 32537.000     40.440     12.347     1.000     40.000
#
#                       50%        75%         max
# age                37.000     48.000      90.000
# fnlwgt         178356.000 236993.000 1484705.000
# education-num      10.000     12.000      16.000
# capital-gain        0.000      0.000   99999.000
# capital-loss        0.000      0.000    4356.000
# hours-per-week     40.000     45.000      99.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/HnG6Xdn/US-Citicens2.png)

# %% [markdown]
# ### Basically check the missing values. (NaN, None)

# %%
# Check the sum of Missing Values per column
# Your Code is Here

df.isna().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education-num      802
# marital-status       0
# occupation           0
# relationship      5064
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %% [raw]
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education_num      802
# marital_status       0
# occupation           0
# relationship      5064
# race                 0
# gender               0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country       0
# salary               0
# dtype: int64

# %%
# Check the Percentage of Missing Values
# Your Code is Here
missing_values_sum = df.isna().sum()

# Calculate the percentage of missing values per column
total_rows = len(df)
missing_values_percentage = (missing_values_sum / total_rows) * 100
missing_values_percentage
# Out:
# age               0.000
# workclass         0.000
# fnlwgt            0.000
# education         0.000
# education-num     2.465
# marital-status    0.000
# occupation        0.000
# relationship     15.564
# race              0.000
# sex               0.000
# capital-gain      0.000
# capital-loss      0.000
# hours-per-week    0.000
# native-country    0.000
# salary            0.000
# dtype: float64

# %% [raw]
# Desired Output:
#
# age               0.000
# workclass         0.000
# fnlwgt            0.000
# education         0.000
# education_num     2.465
# marital_status    0.000
# occupation        0.000
# relationship     15.564
# race              0.000
# gender            0.000
# capital_gain      0.000
# capital_loss      0.000
# hours_per_week    0.000
# native_country    0.000
# salary            0.000
# dtype: float64

# %% [markdown]
# ### If needed, rename the columns' names for easy use.

# %% [markdown]
# **Rename the features of;**<br>
# **``"education-num"``**, **``"marital-status"``**, **``"capital-gain"``**, **``"capital-loss"``**, **``"hours-per-week"``**, **``"native-country"``** **as**<br>
# **``"education_num"``**, **``"marital_status"``**, **``"capital_gain"``**, **``"capital_loss"``**, **``"hours_per_week"``**, **``"native_country"``**, **respectively and permanently.**

# %%
# Your Code is Here
df.rename(columns={'education-num': 'education_num', 'marital-status':'marital_status', 'capital-gain' : 'capital_gain', 
                  'capital-loss':'capital_loss' , 'hours-per-week':'hours_per_week', 'native-country': 'native_country'
                  },
          inplace=True)
df
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors         13.000
# 1       50  Self-emp-not-inc   83311   Bachelors         13.000
# 2       38           Private  215646     HS-grad          9.000
# 3       53           Private  234721        11th          7.000
# 4       28           Private  338409   Bachelors         13.000
# ...    ...               ...     ...         ...            ...
# 32532   27           Private  257302  Assoc-acdm         12.000
# 32533   40           Private  154374     HS-grad          9.000
# 32534   58           Private  151910     HS-grad          9.000
# 32535   22           Private  201490     HS-grad          9.000
# 32536   52      Self-emp-inc  287927     HS-grad          9.000
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32532  Married-civ-spouse       Tech-support           Wife  White  Female
# 32533  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32534             Widowed       Adm-clerical      Unmarried  White  Female
# 32535       Never-married       Adm-clerical            NaN  White    Male
# 32536  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital_gain  capital_loss  hours_per_week native_country salary
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32532             0             0              38  United-States  <=50K
# 32533             0             0              40  United-States   >50K
# 32534             0             0              40  United-States  <=50K
# 32535             0             0              20  United-States  <=50K
# 32536         15024             0              40  United-States   >50K
#
# [32537 rows x 15 columns]

# %% [markdown]
# ## Examining the Data
# - Look at the counts of columns that have OBJECT datatype
# - Assign the Columns (Features) of object data type as** **`"object_col"`**
# - Detect strange values apart from the NaN Values.(isin(),Count(),Sum(),Any())

# %% [markdown]
# ### Look at the value counts of columns that have OBJECT datatype

# %%
# Your Code is Here

df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %% [raw]
# Desired Output:
#
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'gender',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %%
# Your Code is Here

object_columns= df.select_dtypes(include=['object'])

a = df.select_dtypes(include=['object']).agg( [ 'count',  'nunique',
                                         lambda x: x.value_counts().index[0], 
                                        lambda x: x.value_counts().iloc[0] ]).transpose()

a.columns = ['count', 'unique', 'top', 'freq']
a
# Out:
#                 count unique                 top   freq
# workclass       32537      9             Private  22673
# education       32537     16             HS-grad  10494
# marital_status  32537      7  Married-civ-spouse  14970
# occupation      32537     15      Prof-specialty   4136
# relationship    27473      5             Husband  13187
# race            32537      5               White  27795
# sex             32537      2                Male  21775
# native_country  32537     42       United-States  29153
# salary          32537      2               <=50K  24698

# %%
df.select_dtypes(include=['object']).describe().T
# Out:
#                 count unique                 top   freq
# workclass       32537      9             Private  22673
# education       32537     16             HS-grad  10494
# marital_status  32537      7  Married-civ-spouse  14970
# occupation      32537     15      Prof-specialty   4136
# relationship    27473      5             Husband  13187
# race            32537      5               White  27795
# sex             32537      2                Male  21775
# native_country  32537     42       United-States  29153
# salary          32537      2               <=50K  24698

# %%
df.describe(include=['O']).T
# Out:
#                 count unique                 top   freq
# workclass       32537      9             Private  22673
# education       32537     16             HS-grad  10494
# marital_status  32537      7  Married-civ-spouse  14970
# occupation      32537     15      Prof-specialty   4136
# relationship    27473      5             Husband  13187
# race            32537      5               White  27795
# sex             32537      2                Male  21775
# native_country  32537     42       United-States  29153
# salary          32537      2               <=50K  24698

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/WspBGfZ/US-Citicens3.png)

# %% [markdown]
# ### Assign the Columns (Features) of object data type as** **``"object_col"``

# %%
# Your Code is Here
object_col=df.select_dtypes(include=['object']).columns
object_col
# Out:
# Index(['workclass', 'education', 'marital_status', 'occupation',
#        'relationship', 'race', 'sex', 'native_country', 'salary'],
#       dtype='object')

# %% [raw]
# Desired Output:
#
# Index(['workclass', 'education', 'marital_status', 'occupation',
#        'relationship', 'race', 'gender', 'native_country', 'salary'],
#       dtype='object')

# %%
for col in object_col:
    print(col)
    print("**"*20)
    print(df[col].value_counts(dropna=False))
    print("--"*20)
# Out:
# workclass
# ****************************************
# workclass
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64
# ----------------------------------------
# education
# ****************************************
# education
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: count, dtype: int64
# ----------------------------------------
# marital_status
# ****************************************
# marital_status
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: count, dtype: int64
# ----------------------------------------
# occupation
# ****************************************
# occupation
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: count, dtype: int64
# ----------------------------------------
# relationship
# ****************************************
# relationship
# Husband           13187
# Not-in-family      8292
# NaN                5064
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: count, dtype: int64
# ----------------------------------------
# race
# ****************************************
# race
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: count, dtype: int64
# ----------------------------------------
# sex
# ****************************************
# sex
# Male      21775
# Female    10762
# Name: count, dtype: int64
# ----------------------------------------
# native_country
# ****************************************
# native_country
# United-States                 29153
# Mexico                          639
# ?                               582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# France                           29
# Greece                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Cambodia                         19
# Trinadad&Tobago                  19
# Laos                             18
# Thailand                         18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Honduras                         13
# Hungary                          13
# Scotland                         12
# Holand-Netherlands                1
# Name: count, dtype: int64
# ----------------------------------------
# salary
# ****************************************
# salary
# <=50K    24698
# >50K      7839
# Name: count, dtype: int64
# ----------------------------------------

# %% [markdown]
# ### Detect strange values apart from the NaN Values.(isin(),Count(),Sum(),Any())

# %% [markdown]
# **Check if the Dataset has any Question Mark** **``"?"``**

# %%
# Your Code is Here
df.apply(lambda x: x.astype(str).str.contains('\?').any())
# Out:
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education_num     False
# marital_status    False
# occupation         True
# relationship      False
# race              False
# sex               False
# capital_gain      False
# capital_loss      False
# hours_per_week    False
# native_country     True
# salary            False
# dtype: bool

# %% [raw]
# Desired Output:
#
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education_num     False
# marital_status    False
# occupation         True
# relationship      False
# race              False
# gender            False
# capital_gain      False
# capital_loss      False
# hours_per_week    False
# native_country     True
# salary            False
# dtype: bool

# %% [markdown]
# <a id="4"></a>
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;">Univariate & Multivariate Analysis</p>
#
# <a href="#content" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Examine all Features:
# - **Target Feature**
# - **Numeric Ones**
# - **Categoric Ones** separately from different aspects according to target feature.
#
# **to do list for numeric features:**
# 1. Check the boxplot to see extreme values
# 2. Check the histplot/kdeplot to see distribution of feature
# 3. Check the statistical values
# 4. Check the boxplot and histplot/kdeplot by target feature
# 5. Check the statistical values by target feature
# 6. Write down the conclusions you draw from your analysis
#
# **to do list for categoric features:**
# 1. Find the features which contains similar values, examine the similarities and analyze them together
# 2. Check the count/percentage in each categories and visualize it with a suitable plot
# 3. If need, decrease the number of categories by combining similar categories
# 4. Check the count/percentage in each target feature by categories and visualize it with a suitable plot
# 5. Check the percentage distribution in each target feature by categories and visualize it with suitable plot
# 6. Check the count in each categories by target feature and visualize it with a suitable plot
# 7. Check the percentage distribution in each categories by target feature and visualize it with suitable plot
# 8. Write down the conclusions you draw from your analysis
#
# **Note :** **Instruction/direction** for each feature is available under the corresponding feature in detail, as well.

# %% [markdown]
# ## Target Feature
# - Salary

# %% [markdown]
# **Check the count of person in each "salary" levels and visualize it with a countplot**

# %%
# Your Code is Here

df['salary'].value_counts()
# Out:
# salary
# <=50K    24698
# >50K      7839
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# <=50K    24698
# >50K      7839
# Name: salary, dtype: int64

# %%
# Your Code is Here
plt.figure(figsize=(9, 5))
sns.set_style("whitegrid")
ax =sns.countplot(data=df, x='salary', palette="tab10")
for container in ax.containers:
    ax.bar_label(container,fmt='%1.f',fontsize=8 );

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/9qwrtB1/US-Citicens4.png)

# %% [markdown]
# **Check the percentage of person in each "salary" levels and visualize it with a pieplot**

# %%
# Your Code is Here
salary_percentages = df['salary'].value_counts(normalize=True)
salary_percentages
# Out:
# salary
# <=50K   0.759
# >50K    0.241
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# <=50K   0.759
# >50K    0.241
# Name: salary, dtype: float64

# %%
# Your Code is Here
plt.figure(figsize=(7, 5))
#plt.rcParams.update({'font.size': 12}) 
myexplode = [0, 0.1]
mycolors= ["lightskyblue", "yellow"]
plt.pie(salary_percentages, labels=salary_percentages.index, autopct='%1.1f%%',
        explode= myexplode, pctdistance =0.5, shadow=True, colors = mycolors)
plt.title('Percentage of Income-Level',fontsize=13)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/8YFvBrq/US-Citices5.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** .................

# %% [markdown]
# -> Gelirlerin yüzde 75,9'u 50 binin altında
# -> Gelirlerin yüzde 24,1'i 50 binin altında
# Gözlenen degerlerin büyük cogunlugunun 50K'dan düsük gelirinin oldugunu görüyoruz.

# %% [markdown]
# ## Numeric Features

# %% [markdown]
# ### age

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here

sns.boxplot(data=df, x="age", showmeans=False);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/JKKwy5K/US-Citizens6.png)

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here
sns.color_palette("husl", 8)
sns.histplot(data=df, x="age", kde=True,  alpha=0.5, bins= 20) 
plt.xlabel("age")
#plt.ylabel("Count",fontsize=9)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/JcJ9cyp/US-Citizens7.png)

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here
df["age"].describe()
# Out:
# count   32537.000
# mean       38.586
# std        13.638
# min        17.000
# 25%        28.000
# 50%        37.000
# 75%        48.000
# max        90.000
# Name: age, dtype: float64

# %% [raw]
# Desired Output:
#
# count   32537.000
# mean       38.586
# std        13.638
# min        17.000
# 25%        28.000
# 50%        37.000
# 75%        48.000
# max        90.000
# Name: age, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors         13.000
# 1       50  Self-emp-not-inc   83311   Bachelors         13.000
# 2       38           Private  215646     HS-grad          9.000
# 3       53           Private  234721        11th          7.000
# 4       28           Private  338409   Bachelors         13.000
# ...    ...               ...     ...         ...            ...
# 32532   27           Private  257302  Assoc-acdm         12.000
# 32533   40           Private  154374     HS-grad          9.000
# 32534   58           Private  151910     HS-grad          9.000
# 32535   22           Private  201490     HS-grad          9.000
# 32536   52      Self-emp-inc  287927     HS-grad          9.000
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32532  Married-civ-spouse       Tech-support           Wife  White  Female
# 32533  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32534             Widowed       Adm-clerical      Unmarried  White  Female
# 32535       Never-married       Adm-clerical            NaN  White    Male
# 32536  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital_gain  capital_loss  hours_per_week native_country salary
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32532             0             0              38  United-States  <=50K
# 32533             0             0              40  United-States   >50K
# 32534             0             0              40  United-States  <=50K
# 32535             0             0              20  United-States  <=50K
# 32536         15024             0              40  United-States   >50K
#
# [32537 rows x 15 columns]

# %%
plt.figure(figsize=(9,5))
sns.boxplot(data=df, x= "salary", y="age",showmeans=False, palette="tab10");

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/64tBVNT/US-Citizens8.png)

# %%
# Your Code is Here
plt.figure(figsize=(8,5))
sns.histplot(data=df, x="age", hue="salary", kde=True, color='skyblue', alpha=0.5, bins= 20);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/q5P0sVf/US-Citizens9.png)

# %%
# Your Code is Here
plt.figure(figsize=(8,5))
sns.kdeplot(data=df, x="age", hue="salary", fill=True, alpha=0.2,palette="tab10" );

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/7Y2HkxB/US-Citizens10.png)

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here
df.groupby("salary")["age"].describe()
# Out:
#            count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  24698.000 36.787 14.017 17.000 25.000 34.000 46.000 90.000
# >50K    7839.000 44.251 10.520 19.000 36.000 44.000 51.000 90.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/xYYZcZZ/US-Citizens11.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# Result :
# Bu istatistikler, veri setinin yaş değişkeninin dağılımı hakkında bir fikir verir.
# Örneğin, yaş değerlerinin çoğunluğunun 28 ila 48 arasında olduğunu görebiliriz,
# ancak veri setinde 17 ile 90 yaş arasında geniş bir dağılım olduğunu da gözlemleyebiliriz.
# 1. Dağılımın Sağa Çarpık Olduğu: Veri setinin sağa çarpık olduğunu gösterir.
#     Yani, verinin çoğunluğu daha yüksek değerlerde yoğunlaşmıştır.
#
# 2. Aykırı Değerlerin Olabilirliği: Sağ whiskerın sol whiskerden daha uzun olması,
#     sağ taraftaki aykırı değerlerin daha fazla olduğunu düşündürebilir. Boxplota bakildiginda sag tarafda
#     outlier yogunlugu oldugunu görebiliriz.
#
# 3. Dağılımın Merkezinin ve Yayılımının Değerlendirilmesi: Whisker uzunlukları, veri setinin merkezi ve yayılımı
#     hakkında daha fazla bilgi sağlar. Sağ whiskerın uzunluğu, veri setinin genellikle sağa doğru uzanıp (right skewed) yüksek
#     değerlerde daha fazla yayıldığını gösterir.
#
# 4. Dağılımın İnce Detayları Hakkında Düşünmek: Sağ whiskerin uzunluğu, verinin yüksek değerlerine odaklanılmasını gerektirir.
#     Bu, veri setinin genel yapısını değerlendirirken daha yüksek yaşlara sahip bireylerin etkilerini daha iyi anlamak için
#     daha fazla analizin yapılması gerektiği anlamına gelir.
# Maaslari 2 gruba ayirip baktigimizda ise:
# 1. Ortalama Maaş: >50K maaş grubunun ortalama maaşı, <=50K maaş grubunun ortalama maaşından daha yüksektir. Bu, genel olarak daha yüksek maaş alan bireylerin olduğunu gösterir.
#
# 2. Standart Sapma: >50K maaş grubunun standart sapması, <=50K maaş grubununkinden daha düşüktür. Bu, >50K maaş grubundaki maaşların daha homojen bir dağılıma sahip olduğunu gösterebilir.
#
# 3. Medyan Maaş: Medyan maaş, her iki grup için de ortalama maaştan daha düşüktür. Bu, veri setindeki aykırı değerlerin, ortalama değeri etkileyerek yukarı doğru çektiğini gösterebilir.
#
# 4. Çeyreklikler: >50K maaş grubunun alt, medyan ve üst çeyrekleri, <=50K maaş grubununkinden daha yüksektir. Bu da, >50K maaş grubundaki dağılımın, genel olarak daha yüksek maaş değerlerine doğru kaydığını gösterir.
#
# Sonuç olarak, bu istatistikler, farklı maaş grupları arasında belirgin farklılıklar olduğunu ve >50K maaş grubunun genellikle daha yüksek maaşlara sahip olduğunu gösterir. Bu bilgiler, maaş gruplarının genel yapısını ve dağılımını anlamak için kullanılabilir.

# %% [markdown]
# ###fnlwgt

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here
plt.figure(figsize=(8,5))
sns.boxplot(data=df,  x= "fnlwgt",showmeans=False,palette="tab10" );

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/x2TtkzH/US-Citizens12.png)

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here

plt.figure(figsize=(8,5))
sns.kdeplot(data=df, x="fnlwgt", fill=True , alpha=0.2);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/ZmMV8nv/US-Citizens13.png)

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here
df["fnlwgt"].describe()
# Out:
# count     32537.000
# mean     189780.849
# std      105556.471
# min       12285.000
# 25%      117827.000
# 50%      178356.000
# 75%      236993.000
# max     1484705.000
# Name: fnlwgt, dtype: float64

# %% [raw]
# Desired Output:
#
# count     32537.000
# mean     189780.849
# std      105556.471
# min       12285.000
# 25%      117827.000
# 50%      178356.000
# 75%      236993.000
# max     1484705.000
# Name: fnlwgt, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x= "salary", y="fnlwgt",showmeans=False, palette="tab10");

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/ZxJS7JW/US-Citizens14.png)

# %%
# Your Code is Here
plt.figure(figsize=(7,4))
sns.kdeplot(data=df, x="fnlwgt", hue="salary", fill=True , alpha=0.2);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/TgygLrz/US-Citizens15.png)

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

df.groupby("salary")["fnlwgt"].describe()
# Out:
#            count       mean        std       min        25%        50%  \
# salary
# <=50K  24698.000 190345.927 106487.413 12285.000 117606.000 179465.000
# >50K    7839.000 188000.481 102554.464 14878.000 119100.000 176063.000
#
#               75%         max
# salary
# <=50K  238968.250 1484705.000
# >50K   230969.000 1226583.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/LzWqdBf/US-Citizens16.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** ...............

# %% [markdown]
# Conclusions:
#
# Istatistiksel özete göre,Veri setindeki fnlwgt değerlerinin genellikle yüksek olduğunu, ancak büyük bir yayılım olduğunu görüyoruz. Özellikle, fnlwgt değerlerinin medyanı olan 178,356, ortalama olan 189,780.849'den biraz daha düşüktür, bu da sağa çarpık bir dağılım olduğunu gösterebilir. Ayrıca, standart sapmanın büyük olması, fnlwgt değerlerinin geniş bir yelpazede değiştiğini ve belirgin bir varyasyon gösterdiğini gösterir.
#
# Boxplota baktigimizda outleir'larin hepsinin sag tarafda biriktigini ve cok sayida oldugunu görüyoruz. Buna göre saga carpik
# (right skewed) bir veri setimiz oldugunu yani verilerin yüksek degerlerde toplandigini ve cok fazla extrem büyük degerler oldugunu söyleyebiliriz.
#
# Salary feature'i ile beraber baktigimizda:
# Sonuç olarak, bu istatistikler, maaş grupları arasında fnlwgt değişkeni üzerinde bazı farklılıklar olduğunu ancak bu farklılıkların görece küçük olduğunu göstermektedir. Bu, fnlwgt'nin maaş grubu üzerindeki etkisinin sınırlı olduğunu düşündürebilir.

# %% [markdown]
# ### capital_gain

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here
plt.figure(figsize=(7,4))
sns.boxplot(data=df, x="capital_gain");

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/6Xj1TCz/US-Citizens17.png)

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here

plt.figure(figsize=(7,4))
sns.kdeplot(data=df, x="capital_gain", fill=True , alpha=0.2);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/X3nW72Q/US-Citizens18.png)

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

df["capital_gain"].describe()
# Out:
# count   32537.000
# mean     1078.444
# std      7387.957
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max     99999.000
# Name: capital_gain, dtype: float64

# %% [raw]
# Desired Output:
#
# count   32537.000
# mean     1078.444
# std      7387.957
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max     99999.000
# Name: capital_gain, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here

plt.figure(figsize=(7,4))
sns.boxplot(data=df, x= "salary", y="capital_gain",showmeans=False);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/CM3cTgt/19.png)

# %%
# Your Code is Here
plt.figure(figsize=(7,4))
sns.kdeplot(data=df, x="capital_gain", hue="salary", fill=True , alpha=0.2);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/h7DKvLY/20.png)

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

df.groupby("salary")["capital_gain"].describe()
# Out:
#            count     mean       std   min   25%   50%   75%       max
# salary
# <=50K  24698.000  148.885   963.558 0.000 0.000 0.000 0.000 41310.000
# >50K    7839.000 4007.165 14572.097 0.000 0.000 0.000 0.000 99999.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/mzYxTD4/21.png)

# %% [markdown]
# **Check the statistical values by "salary" levels for capital_gain not equal the zero**

# %%
# Your Code is Here
non_zero_capital_gain = df[df['capital_gain'] != 0]
non_zero_capital_gain.groupby('salary')['capital_gain'].describe()
# Out:
#           count      mean       std      min      25%      50%       75%  \
# salary
# <=50K  1035.000  3552.813  3173.419  114.000 2202.000 3273.000  4101.000
# >50K   1677.000 18731.165 26778.676 3103.000 7298.000 7896.000 15024.000
#
#              max
# salary
# <=50K  41310.000
# >50K   99999.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/r3mdBkK/22.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** ...........................

# %% [markdown]
# Conclusions:
# Sonuçlar: Çoğu gözlemin sermaye kazancı 0'dır, ancak bazı gözlemlerin 0'dan farklı kazançlar elde ettiği belirtilmektedir. Yüksek standart sapma, sermaye kazancı değerlerinin geniş bir yelpazede değiştiğini ve belirgin bir varyasyon gösterdiğini gösterir. Bu istatistikler, veri setinin sermaye kazancı değişkeni üzerindeki genel dağılımını özetler ve sermaye kazancının çoğunluğunun 0 olduğunu gösterir.
# Boxplot incelendiğinde:
# 1.	<=50K ve >50K Maaş Grupları Arasındaki Fark: Kutu grafiğinin alt kısmı (çeyrekler arası mesafe) ve üst kısmı (çeyrekler arası mesafe) arasındaki farklar, iki maaş grubu arasındaki sermaye kazancı dağılımındaki farkları gösterir.
# 2.	Aykırı Değerler: Her iki maaş grubunda da aykırı değerler bulunmaktadır. Bu aykırı değerler, maaş grubuna bağlı olarak farklılık gösterebilir ve genellikle daha yüksek sermaye kazançlarını temsil eder.
# 3.	Sıfır Sermaye Kazancı: Her iki maaş grubunda da kutunun alt kısmı ve üst kısmı (çeyrekler arası mesafe) 0'a yakındır. Bu, çoğu bireyin sermaye kazancının 0 olduğunu gösterir.
# 4.	Ortalama Sermaye Kazancı: Grafiğin ortasında yer alan çizgiler, her bir maaş grubunun ortalama sermaye kazancını gösterir. Görsel olarak, >50K maaş grubunun ortalama sermaye kazancının <=50K maaş grubununkinden biraz daha yüksek olduğu görülmektedir.
# Genel olarak, her iki maaş grubunda da sermaye kazancının çoğunluğunun 0 olduğunu gösterirken, >50K maaş grubunda daha yüksek sermaye kazancı potansiyeline sahip bireylerin olduğu da gözlemlenebilir. 2 grupta da sağ tarafta çok fazla aykırı değer olduğu görülebilir. Verilerin büyük kısmı dar bir aralıkta dağılmıştır.

# %% [markdown]
# ### capital_loss

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here

plt.figure(figsize=(7,4))
sns.boxplot(data=df, x="capital_loss",showmeans=False );

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Db3XHKz/23.png)

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here

plt.figure(figsize=(7,4))
sns.kdeplot(data=df, x="capital_loss" ,fill=True);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/z7P15zX/24.png)

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

df["capital_loss"].describe()
# Out:
# count   32537.000
# mean       87.368
# std       403.102
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max      4356.000
# Name: capital_loss, dtype: float64

# %% [raw]
# Desired Output:
#
# count   32537.000
# mean       87.368
# std       403.102
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max      4356.000
# Name: capital_loss, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here
plt.figure(figsize=(7,4))
sns.boxplot(data=df,x="salary", y="capital_loss",showmeans=False,fill=True );

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Dr7Bv9V/25.png)

# %%
# Your Code is Here

plt.figure(figsize=(7,4))
sns.kdeplot(data=df, x="capital_loss" ,hue="salary",fill=True);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/4Vg5Zyy/26.png)

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

df.groupby('salary')['capital_loss'].describe()
# Out:
#            count    mean     std   min   25%   50%   75%      max
# salary
# <=50K  24698.000  53.190 310.890 0.000 0.000 0.000 0.000 4356.000
# >50K    7839.000 195.051 595.555 0.000 0.000 0.000 0.000 3683.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/h9DTKNW/27.png)

# %% [markdown]
# **Check the statistical values by "salary" levels for capital_loss not equel the zero**

# %%
# Your Code is Here
non_zero_capital_loss = df[df['capital_loss'] != 0]
non_zero_capital_loss.groupby('salary')['capital_loss'].describe()
# Out:
#          count     mean     std     min      25%      50%      75%      max
# salary
# <=50K  746.000 1760.983 438.906 155.000 1590.000 1721.000 1980.000 4356.000
# >50K   773.000 1978.017 264.144 653.000 1887.000 1902.000 1977.000 3683.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/gJzQvmD/28.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# Sonuçlar:
# Çoğu gözlemde sermaye kaybı 0 olarak görünüyor, ancak bazı gözlemlerde 0'dan farklı kayıplar olduğu belirtilmektedir.
# Yüksek standart sapma, sermaye kaybı değerlerinin geniş bir yelpazede değiştiğini ve belirgin bir varyasyon gösterdiğini
# gösterir. Bu istatistikler, veri setindeki sermaye kaybı değişkeninin genel dağılımını özetler ve sermaye kaybının
# çoğunluğunun 0 olduğunu gösterir.
#
# Boxplot incelendiğinde:
#
# 1. Sıfır Sermaye Kaybı: Boxplot grafiğinin alt ve üst kısmı (çeyrekler arası mesafe) 0'a yakındır, bu da çoğu bireyin
#     sermaye kaybının 0 olduğunu gösterir.
#
# 2. Aykırı Değerler: Boxplot grafiğinde, aykiri degerlerin cogu sag tarafdadir. Bu aykırı değerler genellikle daha
#     yüksek sermaye kayıplarını temsil eder.
#
# 3. Ortalama Sermaye Kaybı: Grafiğin ortasında yer alan çizgiler, her bir maaş grubunun ortalama sermaye kaybını gösterir.
#     Görsel olarak, belirli bir eğilim gösteren bir ortalama olabilir.
#
# Genel olarak, çoğu gözlemin sermaye kaybının 0 olduğu görülmektedir, ancak veri setindeki bazı gözlemlerin bu durumdan
# farklı olduğu belirtilmektedir. Yüksek standart sapma, veri setindeki sermaye kaybı değerlerinin geniş bir yayılıma sahip
# olduğunu gösterir.

# %% [markdown]
# ### hours_per_week

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here

plt.figure(figsize=(7,4))
sns.boxplot(data=df,x="hours_per_week",showmeans=False,fill=True );

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/TkNCRYY/29.png)

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here

plt.figure(figsize=(7,4))
sns.kdeplot(data=df,x="hours_per_week", fill=True);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/tsp5GXb/30.png)

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

df.hours_per_week.describe()
# Out:
# count   32537.000
# mean       40.440
# std        12.347
# min         1.000
# 25%        40.000
# 50%        40.000
# 75%        45.000
# max        99.000
# Name: hours_per_week, dtype: float64

# %% [raw]
# Desired Output:
#
# count   32537.000
# mean       40.440
# std        12.347
# min         1.000
# 25%        40.000
# 50%        40.000
# 75%        45.000
# max        99.000
# Name: hours_per_week, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here

plt.figure(figsize=(7,4))
sns.boxplot(data=df,x="salary", y="hours_per_week",showmeans=False,fill=True, palette="tab10" )
plt.xlabel("Salary", fontsize=9)
plt.ylabel("hours_per_week", fontsize=9)
plt.xticks(fontsize=9)
plt.yticks(fontsize=9);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/4RhSct7/31.png)

# %%
# Your Code is Here

plt.figure(figsize=(7,4))
sns.kdeplot(data=df,x="hours_per_week", hue="salary", fill=True);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/pbbVnMG/32.png)

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here
non_zero_capital_loss = df[df['hours_per_week'] != 0]
non_zero_capital_loss.groupby('salary')['hours_per_week'].describe()
# Out:
#            count   mean    std   min    25%    50%    75%    max
# salary
# <=50K  24698.000 38.843 12.318 1.000 35.000 40.000 40.000 99.000
# >50K    7839.000 45.473 11.014 1.000 40.000 40.000 50.000 99.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/6NbWfzz/33.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# Result :
#     .Bu istatistikler, haftalık çalışma saatlerinin dağılımı hakkında bilgi vermektedir.
#     .Gözlemlerinin çoğunluğu 40 saatlik standart bir iş haftasına sahipken, standart sapma oldukça düşük olduğundan,
#     .haftalık çalışma saatlerinin genelde ortalama etrafında yoğunlaştığı söylenebilir.
#
# Ancak, veri setinde minimum ve maksimum değerler arasında oldukça geniş bir yayılma görülüyor.
# Bu, bazı bireylerin minimum veya maksimum iş saatlerinden farklı çalışma saatlerine sahip olduğunu gösterir.
#
# Boxplot ve kde plota bakarak gözlemcilerin cogunlugunun standart 40 saat etrafinda bulundugunun,bu da veri
# setindeki haftalık çalışma saatlerinin çoğunun 40 ile 45 saat arasında olduğunu gösterir.
# Veri setinin saginda ve solunda cok fazla extrem degerler bulunmaktadir.
#
# Salary feature'i ile birlikte bakildiginda:
# 1. Ortalama Haftalık Çalışma Saati: >50K maaş grubunun ortalama haftalık çalışma saati, <=50K maaş grubundan daha yüksektir.
# Standart Sapma: >50K maaş grubunun standart sapması, <=50K maaş grubununkinden daha düşüktür. Bu, >50K maaş grubundaki
# çalışma saatlerinin daha homojen olduğunu gösterebilir.
#
# 2. Minimum ve Maksimum Haftalık Çalışma Saati: Her iki maaş grubunda da minimum ve maksimum haftalık çalışma saatleri aynıdır,
# ancak ortalama saatler arasındaki farklılık dikkat çekicidir. Bu, >50K maaş grubundaki bireylerin genellikle daha uzun
# çalışma saatlerine sahip olduğunu gösterebilir.

# %% [markdown]
# ### See the relationship between each numeric features by target feature (salary) in one plot basically

# %%
# Your Code is Here

sns.pairplot(data=df, hue="salary", corner = True , palette="crest");

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/N7Fz4hg/34.png)

# %% [markdown]
# ## Categorical Features

# %% [markdown]
# ### education & education_num

# %% [markdown]
# **Detect the similarities between these features by comparing unique values**

# %%
# Your Code is Here

df["education"].value_counts()
# Out:
# education
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64

# %%
df.education_num.value_counts(dropna=False)
# Out:
# education_num
# 9.000     10208
# 10.000     7089
# 13.000     5245
# 14.000     1686
# 11.000     1343
# 7.000      1146
# 12.000     1044
# 6.000       916
# NaN         802
# 4.000       630
# 15.000      559
# 5.000       503
# 8.000       424
# 16.000      405
# 3.000       329
# 2.000       159
# 1.000        49
# Name: count, dtype: int64

# %%
df.education_num.value_counts(dropna=False)
# Out:
# education_num
# 9.000     10208
# 10.000     7089
# 13.000     5245
# 14.000     1686
# 11.000     1343
# 7.000      1146
# 12.000     1044
# 6.000       916
# NaN         802
# 4.000       630
# 15.000      559
# 5.000       503
# 8.000       424
# 16.000      405
# 3.000       329
# 2.000       159
# 1.000        49
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# 9.000     10208
# 10.000     7089
# 13.000     5245
# 14.000     1686
# 11.000     1343
# 7.000      1146
# 12.000     1044
# 6.000       916
# NaN         802
# 4.000       630
# 15.000      559
# 5.000       503
# 8.000       424
# 16.000      405
# 3.000       329
# 2.000       159
# 1.000        49
# Name: education_num, dtype: int64

# %%
df.groupby(["education","education_num"],dropna=False).size()
# Out:
# education     education_num
# 10th          6.000              916
#               NaN                 17
# 11th          7.000             1146
#               NaN                 29
# 12th          8.000              424
#               NaN                  9
# 1st-4th       2.000              159
#               NaN                  7
# 5th-6th       3.000              329
#               NaN                  3
# 7th-8th       4.000              630
#               NaN                 15
# 9th           5.000              503
#               NaN                 11
# Assoc-acdm    12.000            1044
#               NaN                 23
# Assoc-voc     11.000            1343
#               NaN                 39
# Bachelors     13.000            5245
#               NaN                108
# Doctorate     16.000             405
#               NaN                  8
# HS-grad       9.000            10208
#               NaN                286
# Masters       14.000            1686
#               NaN                 36
# Preschool     1.000               49
#               NaN                  1
# Prof-school   15.000             559
#               NaN                 17
# Some-college  10.000            7089
#               NaN                193
# dtype: int64

# %%
df.groupby(["education","education_num"],dropna=False)["education_num"].value_counts(dropna=False)
# Out:
# education     education_num
# 10th          6.000              916
#               NaN                 17
# 11th          7.000             1146
#               NaN                 29
# 12th          8.000              424
#               NaN                  9
# 1st-4th       2.000              159
#               NaN                  7
# 5th-6th       3.000              329
#               NaN                  3
# 7th-8th       4.000              630
#               NaN                 15
# 9th           5.000              503
#               NaN                 11
# Assoc-acdm    12.000            1044
#               NaN                 23
# Assoc-voc     11.000            1343
#               NaN                 39
# Bachelors     13.000            5245
#               NaN                108
# Doctorate     16.000             405
#               NaN                  8
# HS-grad       9.000            10208
#               NaN                286
# Masters       14.000            1686
#               NaN                 36
# Preschool     1.000               49
#               NaN                  1
# Prof-school   15.000             559
#               NaN                 17
# Some-college  10.000            7089
#               NaN                193
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# education     education_num
# 10th          6.000              916
#               NaN                 17
# 11th          7.000             1146
#               NaN                 29
# 12th          8.000              424
#               NaN                  9
# 1st-4th       2.000              159
#               NaN                  7
# 5th-6th       3.000              329
#               NaN                  3
# 7th-8th       4.000              630
#               NaN                 15
# 9th           5.000              503
#               NaN                 11
# Assoc-acdm    12.000            1044
#               NaN                 23
# Assoc-voc     11.000            1343
#               NaN                 39
# Bachelors     13.000            5245
#               NaN                108
# Doctorate     16.000             405
#               NaN                  8
# HS-grad       9.000            10208
#               NaN                286
# Masters       14.000            1686
#               NaN                 36
# Preschool     1.000               49
#               NaN                  1
# Prof-school   15.000             559
#               NaN                 17
# Some-college  10.000            7089
#               NaN                193
# Name: education_num, dtype: int64

# %% [markdown]
# **Visualize the count of person in each categories for these features (education, education_num) separately**

# %%
# Your Code is Here
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="education", palette="Set2")
plt.xticks(rotation=90);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/5xc31HR/35.png)

# %%
# Your Code is Here

plt.figure(figsize=(6,4))
sns.countplot(data=df, x="education_num", palette="tab10");

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/6HWtNN6/36.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by these features (education and education_num) separately and visualize them with countplot**

# %%
# Your Code is Here

df.groupby(["education","salary"],dropna=False)["salary"].value_counts(dropna=False)
# Out:
# education     salary
# 10th          <=50K      871
#               >50K        62
# 11th          <=50K     1115
#               >50K        60
# 12th          <=50K      400
#               >50K        33
# 1st-4th       <=50K      160
#               >50K         6
# 5th-6th       <=50K      316
#               >50K        16
# 7th-8th       <=50K      605
#               >50K        40
# 9th           <=50K      487
#               >50K        27
# Assoc-acdm    <=50K      802
#               >50K       265
# Assoc-voc     <=50K     1021
#               >50K       361
# Bachelors     <=50K     3132
#               >50K      2221
# Doctorate     <=50K      107
#               >50K       306
# HS-grad       <=50K     8820
#               >50K      1674
# Masters       <=50K      763
#               >50K       959
# Preschool     <=50K       50
# Prof-school   <=50K      153
#               >50K       423
# Some-college  <=50K     5896
#               >50K      1386
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# education     salary
# 10th          <=50K      871
#               >50K        62
# 11th          <=50K     1115
#               >50K        60
# 12th          <=50K      400
#               >50K        33
# 1st-4th       <=50K      160
#               >50K         6
# 5th-6th       <=50K      316
#               >50K        16
# 7th-8th       <=50K      605
#               >50K        40
# 9th           <=50K      487
#               >50K        27
# Assoc-acdm    <=50K      802
#               >50K       265
# Assoc-voc     <=50K     1021
#               >50K       361
# Bachelors     <=50K     3132
#               >50K      2221
# Doctorate     >50K       306
#               <=50K      107
# HS-grad       <=50K     8820
#               >50K      1674
# Masters       >50K       959
#               <=50K      763
# Preschool     <=50K       50
# Prof-school   >50K       423
#               <=50K      153
# Some-college  <=50K     5896
#               >50K      1386
# Name: salary, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(6,4))
sns.countplot(data=df, x="education",hue="salary", palette="tab10")
plt.xticks(rotation=90)
plt.legend(loc='upper center');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/qxZXX1y/37.png)

# %%
# Your Code is Here

df.groupby(["education_num","salary"])["salary"].value_counts(dropna=True,ascending=False)
# Out:
# education_num  salary
# 1.000          <=50K       49
# 2.000          <=50K      153
#                >50K         6
# 3.000          <=50K      313
#                >50K        16
# 4.000          <=50K      592
#                >50K        38
# 5.000          <=50K      477
#                >50K        26
# 6.000          <=50K      854
#                >50K        62
# 7.000          <=50K     1088
#                >50K        58
# 8.000          <=50K      391
#                >50K        33
# 9.000          <=50K     8579
#                >50K      1629
# 10.000         <=50K     5746
#                >50K      1343
# 11.000         <=50K      994
#                >50K       349
# 12.000         <=50K      787
#                >50K       257
# 13.000         <=50K     3078
#                >50K      2167
# 14.000         <=50K      751
#                >50K       935
# 15.000         <=50K      149
#                >50K       410
# 16.000         <=50K      103
#                >50K       302
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# education_num  salary
# 1.000          <=50K       49
# 2.000          <=50K      153
#                >50K         6
# 3.000          <=50K      313
#                >50K        16
# 4.000          <=50K      592
#                >50K        38
# 5.000          <=50K      477
#                >50K        26
# 6.000          <=50K      854
#                >50K        62
# 7.000          <=50K     1088
#                >50K        58
# 8.000          <=50K      391
#                >50K        33
# 9.000          <=50K     8579
#                >50K      1629
# 10.000         <=50K     5746
#                >50K      1343
# 11.000         <=50K      994
#                >50K       349
# 12.000         <=50K      787
#                >50K       257
# 13.000         <=50K     3078
#                >50K      2167
# 14.000         >50K       935
#                <=50K      751
# 15.000         >50K       410
#                <=50K      149
# 16.000         >50K       302
#                <=50K      103
# Name: salary, dtype: int64

# %%
# Your Code is Here
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="education_num",hue="salary", palette="tab10")
plt.xticks(rotation=90);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/2M0BYyk/38.png)

# %% [markdown]
# **Visualize the boxplot of "education_num" feature by "salary" levels**

# %%
# Your Code is Here
plt.figure(figsize=(6,4))
sns.boxplot(data=df, x="salary",y="education_num", palette="tab10")
plt.xlabel("salary", fontsize=9)
plt.ylabel("education_num", fontsize=9)
plt.xticks(fontsize=9)
plt.yticks(fontsize=9);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/mSBNzKw/39.png)

# %% [markdown]
# **Decrease the number of categories in "education" feature as low, medium, and high level and create a new feature with this new categorical data.**

# %%
def mapping_education(x):
    if x in ["Preschool", "1st-4th", "5th-6th", "7th-8th", "9th", "10th", "11th", "12th"]:
        return "low_level_grade"
    elif x in ["HS-grad", "Some-college", "Assoc-voc", "Assoc-acdm"]:
        return "medium_level_grade"
    elif x in ["Bachelors", "Masters", "Prof-school", "Doctorate"]:
        return "high_level_grade"

# %%
df["education"].apply( mapping_education).value_counts()
# Out:
# education
# medium_level_grade    20225
# high_level_grade       8064
# low_level_grade        4248
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# medium_level_grade    20225
# high_level_grade       8064
# low_level_grade        4248
# Name: education, dtype: int64

# %%
# By using "mapping_education" def function above, create a new column named "education_summary"
# Your Code is Here
df["education_summary"]= df.education.apply( mapping_education)
df["education_summary"].head()
# Out:
# 0      high_level_grade
# 1      high_level_grade
# 2    medium_level_grade
# 3       low_level_grade
# 4      high_level_grade
# Name: education_summary, dtype: object

# %% [markdown]
# **Visualize the count of person in each categories for these new education levels (high, medium, low)**

# %%
# Your Code is Here
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="education_summary", palette="tab10");

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/cx3Dzn1/40.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by these new education levels(high, medium, low) and visualize it with countplot**

# %%
# Your Code is Here
df.groupby(["education_summary","salary"])["salary"].value_counts(dropna=True,ascending=False)
# Out:
# education_summary   salary
# high_level_grade    <=50K      4155
#                     >50K       3909
# low_level_grade     <=50K      4004
#                     >50K        244
# medium_level_grade  <=50K     16539
#                     >50K       3686
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# education_summary   salary
# high_level_grade    <=50K      4155
#                     >50K       3909
# low_level_grade     <=50K      4004
#                     >50K        244
# medium_level_grade  <=50K     16539
#                     >50K       3686
# Name: salary, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(6,4))
sns.countplot(data=df, x="education_summary",hue="salary", palette="tab10");

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/tXk04LJ/41.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new education levels (high, medium, low) and visualize it with pie plot separately**

# %%
# Your Code is Here
percentage_distribution = df.groupby(['education_summary', 'salary']).size() / df.groupby('education_summary').size()
percentage_distribution
# Out:
# education_summary   salary
# high_level_grade    <=50K    0.515
#                     >50K     0.485
# low_level_grade     <=50K    0.943
#                     >50K     0.057
# medium_level_grade  <=50K    0.818
#                     >50K     0.182
# dtype: float64

# %% [raw]
# Desired Output:
#
# education_summary   salary
# high_level_grade    <=50K    0.515
#                     >50K     0.485
# low_level_grade     <=50K    0.943
#                     >50K     0.057
# medium_level_grade  <=50K    0.818
#                     >50K     0.182
# Name: salary, dtype: float64

# %%
# Your Code is Here


fig, axes = plt.subplots(1, 3, figsize=(13, 4))
mycolors = ['pink', '#86C9EB']
for i, category in enumerate(['high_level_grade', 'low_level_grade','medium_level_grade']):
    percentage_distribution[category].plot(kind='pie', autopct='%1.2f%%', ax=axes[i], colors=mycolors )
    axes[i].set_title( category.capitalize(),pad=20 )
    axes[i].set_ylabel('salary')
    axes[i].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

plt.tight_layout()
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/9W6kXc6/42.png)

# %% [markdown]
# **Check the count of person in each these new education levels(high, medium, low) by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("salary")["education_summary"].value_counts(dropna=True)
# Out:
# salary  education_summary
# <=50K   medium_level_grade    16539
#         high_level_grade       4155
#         low_level_grade        4004
# >50K    high_level_grade       3909
#         medium_level_grade     3686
#         low_level_grade         244
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  education_summary
# <=50K   medium_level_grade    16539
#         high_level_grade       4155
#         low_level_grade        4004
# >50K    high_level_grade       3909
#         medium_level_grade     3686
#         low_level_grade         244
# Name: education_summary, dtype: int64

# %%
# Your Code is Here
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="salary",hue="education_summary", palette="tab10");

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/K9xLxvF/43.png)

# %% [markdown]
# **Check the the percentage distribution of person in each these new education levels(high, medium, low) by "salary" levels and visualize it with pie plot separately**

# %%
# Your Code is Here
percentage_distribution = df.groupby("salary")["education_summary"].value_counts(normalize=True)
percentage_distribution
# Out:
# salary  education_summary
# <=50K   medium_level_grade   0.670
#         high_level_grade     0.168
#         low_level_grade      0.162
# >50K    high_level_grade     0.499
#         medium_level_grade   0.470
#         low_level_grade      0.031
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# salary  education_summary
# <=50K   medium_level_grade   0.670
#         high_level_grade     0.168
#         low_level_grade      0.162
# >50K    high_level_grade     0.499
#         medium_level_grade   0.470
#         low_level_grade      0.031
# Name: education_summary, dtype: float64

# %%
percentage_salary_summary = df.groupby(['salary'])['education_summary'].value_counts(normalize=True)
fig, axs = plt.subplots(1, 2, figsize=(13, 4))  # Genişlik 10 inç, yükseklik 5 inç olarak ayarlandı
mycolors = ['pink', '#86C9EB', '#7DE376']

for i, salary in enumerate(df['salary'].unique()):
    data = percentage_salary_summary[salary]
    if i==0:
        labels = ['(<=50K, Low Level Grade)', '(<=50K, Medium Level Grade)', '(<=50K, High Level Grade)']
    else:
        labels = ['(>=50K, Low Level Grade)', '(>=50K, Medium Level Grade)', '(>=50K, High Level Grade)']
    sizes = data.values * 100
    axs[i].set_title(salary, pad=20)  
    axs[i].pie(sizes, labels=labels, autopct='%1.2f%%', colors=mycolors, startangle=360)
    axs[i].axis('equal')
    axs[i].set_ylabel('education_summary') 
    plt.tight_layout()
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/42pnNPc/44.png)

# %%
# Your Code is Here

my_df = df.groupby('salary')['education_summary'].value_counts(normalize = True).reset_index()
my_df = my_df.rename(columns={'proportion' : "percentage"})
my_df = my_df.sort_values(by = ['salary', 'education_summary'])
my_df
# Out:
#   salary   education_summary  percentage
# 1  <=50K    high_level_grade       0.168
# 2  <=50K     low_level_grade       0.162
# 0  <=50K  medium_level_grade       0.670
# 3   >50K    high_level_grade       0.499
# 5   >50K     low_level_grade       0.031
# 4   >50K  medium_level_grade       0.470

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/jHYrhz8/45.png)

# %%
percentage_salary_summary = df.groupby('salary')['education_summary'].value_counts(normalize = True)
fig, axs = plt.subplots(1, 2, figsize=(16, 4))  # Genişlik 10 inç, yükseklik 5 inç olarak ayarlandı
mycolors = ['#7DE376','pink' ,'#86C9EB', ]
for i, salary in enumerate(my_df['salary'].unique()):
    data = percentage_salary_summary[salary]
    labels = data.index    
    short_labels = [label.split('_')[0] for label in labels]
    sizes = data.values * 100
    axs[i].set_title(salary, pad=15,fontsize=10)  
    axs[i].pie(sizes, labels=short_labels, autopct='%1.2f%%', colors=mycolors, startangle=95*(i+1) ,textprops={'fontsize': 8})
    
    axs[i].set_ylabel('percentage',fontsize=8) 
    plt.tight_layout()
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/5BnYV6h/46.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# Result :
#   ->  10th, 11th, 12th, 1st-4th, 5th-6th, 7th-8th, 9th: Bu düşük eğitim seviyelerine sahip bireylerin çoğunluğu
#     <=50K maaş aralığında yer alırken, >50K maaş aralığında daha az sayıda kişi bulunmaktadır. Bu, düşük eğitim
#     seviyelerinin genellikle daha düşük maaşlarla ilişkilendirildiğini göstermektedir.
#
#  ->  Assoc-acdm, Assoc-voc, Bachelors, Doctorate, HS-grad, Masters, Preschool, Prof-school, Some-college:
#     Bu daha yüksek eğitim seviyelerine sahip bireylerin çoğu >50K maaş aralığında yer almaktadır. Özellikle,
#     Doktora ve Profesyonel Okul mezunları genellikle >50K maaş aralığında yer almaktadır. Buna karşılık, bazı
#     eğitim seviyeleri (örneğin, HS-grad) hem <=50K hem de >50K maaş aralıklarında önemli sayıda bireyi içermektedir.
#
# Daha yüksek eğitim seviyesine sahip bireylerin genellikle daha yüksek maaşlar aldığı görülmektedir,
# ancak bazı eğitim seviyelerinde maaş aralıklarında önemli bir çeşitlilik bulunmaktadır.
#
# 50K'dan düsük maas alanlarin cogunlugu medium level egitim seviyesindeyken, yaklasik %16'si yüksek egitim seviyesindedir.
# 50K'dan büyük maas alanlarin neredeyse yarisi medium level ve diger yarisi high level segitim seviyesindedir.
#
# Sonuc olarak: Daha yüksek düzeyde eğitim almış bireylerin genellikle daha yüksek maaş aralıklarında olduğu görülmektedir.
# Özellikle, >50K maaş aralığında, yüksek düzeyde eğitim almış bireylerin oranı diğerlerine göre belirgin şekilde daha yüksektir.
# Bu veriler, eğitim seviyesinin maaş üzerinde önemli bir etkisi olduğunu göstermektedir.

# %% [markdown]
# ### marital_status & relationship

# %% [markdown]
# **Detect the similarities between these features by comparing unique values**

# %%
# Your Code is Here

df.marital_status.value_counts()
# Out:
# marital_status
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64

# %%
# Your Code is Here
df.relationship.value_counts()
# Out:
# relationship
# Husband           13187
# Not-in-family      8292
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# Husband           13187
# Not-in-family      8292
# NaN                5064
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
# Fill missing values with "Unknown" in the column of "relationship"

# Your Code is Here

df['relationship'] = df['relationship'].fillna('Unknown')
df['relationship']
# Out:
# 0        Not-in-family
# 1              Husband
# 2        Not-in-family
# 3              Husband
# 4                 Wife
#              ...
# 32532             Wife
# 32533          Husband
# 32534        Unmarried
# 32535          Unknown
# 32536             Wife
# Name: relationship, Length: 32537, dtype: object

# %%
# Your Code is Here

df.groupby("relationship")["marital_status"].value_counts()
# Out:
# relationship    marital_status
# Husband         Married-civ-spouse       13178
#                 Married-AF-spouse            9
# Not-in-family   Never-married             4694
#                 Divorced                  2403
#                 Widowed                    547
#                 Separated                  420
#                 Married-spouse-absent      211
#                 Married-civ-spouse          17
# Other-relative  Never-married              611
#                 Married-civ-spouse         124
#                 Divorced                   110
#                 Separated                   55
#                 Widowed                     48
#                 Married-spouse-absent       32
#                 Married-AF-spouse            1
# Unknown         Never-married             4481
#                 Divorced                   328
#                 Separated                   99
#                 Married-civ-spouse          95
#                 Married-spouse-absent       45
#                 Widowed                     15
#                 Married-AF-spouse            1
# Unmarried       Divorced                  1600
#                 Never-married              881
#                 Separated                  451
#                 Widowed                    383
#                 Married-spouse-absent      130
# Wife            Married-civ-spouse        1556
#                 Married-AF-spouse           12
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# relationship    marital_status
# Husband         Married-civ-spouse       13178
#                 Married-AF-spouse            9
# Not-in-family   Never-married             4694
#                 Divorced                  2403
#                 Widowed                    547
#                 Separated                  420
#                 Married-spouse-absent      211
#                 Married-civ-spouse          17
# Other-relative  Never-married              611
#                 Married-civ-spouse         124
#                 Divorced                   110
#                 Separated                   55
#                 Widowed                     48
#                 Married-spouse-absent       32
#                 Married-AF-spouse            1
# Unknown         Never-married             4481
#                 Divorced                   328
#                 Separated                   99
#                 Married-civ-spouse          95
#                 Married-spouse-absent       45
#                 Widowed                     15
#                 Married-AF-spouse            1
# Unmarried       Divorced                  1600
#                 Never-married              881
#                 Separated                  451
#                 Widowed                    383
#                 Married-spouse-absent      130
# Wife            Married-civ-spouse        1556
#                 Married-AF-spouse           12
# Name: marital_status, dtype: int64

# %% [markdown]
# **Assessment :** "İlişki" sütunu, ele alınması gereken önemli sayıda eksik değer (5.064) içerir. Bu eksik değerler, diğer özelliklere dayalı atama gibi uygun bir stratejiyle veya basitçe "Bilinmeyen" gibi bir yer tutucu değerle doldurulabilir.
# Verilerin "ilişki" ve "medeni_durum" sütunlarında sırasıyla "Koca" ve "Evli-vatandaş-eş" gibi belirli kategorilere göre çarpık olduğu görülüyor. Bu, veri kümesinin demografik özelliklerini veya veri toplamadaki olası önyargıları yansıtıyor olabilir. Bu kalıpları daha iyi anlamak için daha fazla araştırma yapılması gerekebilir.

# %% [markdown]
# **Visualize the count of person in each categories**

# %%
# Your Code is Here
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="marital_status", palette="tab10")

plt.xticks(rotation=45);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/1RNHVvj/47.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by categories and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("marital_status")["salary"].value_counts()
# Out:
# marital_status         salary
# Divorced               <=50K      3978
#                        >50K        463
# Married-AF-spouse      <=50K        13
#                        >50K         10
# Married-civ-spouse     <=50K      8280
#                        >50K       6690
# Married-spouse-absent  <=50K       384
#                        >50K         34
# Never-married          <=50K     10176
#                        >50K        491
# Separated              <=50K       959
#                        >50K         66
# Widowed                <=50K       908
#                        >50K         85
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# marital_status         salary
# Divorced               <=50K      3978
#                        >50K        463
# Married-AF-spouse      <=50K        13
#                        >50K         10
# Married-civ-spouse     <=50K      8280
#                        >50K       6690
# Married-spouse-absent  <=50K       384
#                        >50K         34
# Never-married          <=50K     10176
#                        >50K        491
# Separated              <=50K       959
#                        >50K         66
# Widowed                <=50K       908
#                        >50K         85
# Name: salary, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(6,4))
sns.countplot(data=df, x="marital_status",hue="salary", palette="tab10")

plt.xticks(rotation=45, fontsize=9);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/qjNhW9h/48.png)

# %% [markdown]
# **Decrease the number of categories in "marital_status" feature as married, and unmarried and create a new feature with this new categorical data**

# %%
def mapping_marital_status(x):
    if x in ["Never-married", "Divorced", "Separated", "Widowed"]:
        return "unmarried"
    elif x in ["Married-civ-spouse", "Married-AF-spouse", "Married-spouse-absent"]:
        return "married"

# %%
# Your Code is Here

df["marital_status"].apply( mapping_marital_status).value_counts()
# Out:
# marital_status
# unmarried    17126
# married      15411
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# unmarried    17126
# married      15411
# Name: marital_status, dtype: int64

# %%
# By using "mapping_marital_status" def function above, create a new column named "marital_status_summary"

# Your Code is Here
df["marital_status_summary"]=df["marital_status"].apply(mapping_marital_status)
df["marital_status_summary"]
# Out:
# 0        unmarried
# 1          married
# 2        unmarried
# 3          married
# 4          married
#            ...
# 32532      married
# 32533      married
# 32534    unmarried
# 32535    unmarried
# 32536      married
# Name: marital_status_summary, Length: 32537, dtype: object

# %% [markdown]
# **Visualize the count of person in each categories for these new marital status (married, unmarried)**

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="marital_status_summary", palette="tab10")
plt.xlabel("marital_status_summary", fontsize=9);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/wRjj6Bx/49.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by these new marital status (married, unmarried) and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("marital_status_summary")["salary"].value_counts()
# Out:
# marital_status_summary  salary
# married                 <=50K      8677
#                         >50K       6734
# unmarried               <=50K     16021
#                         >50K       1105
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# marital_status_summary  salary
# married                 <=50K      8677
#                         >50K       6734
# unmarried               <=50K     16021
#                         >50K       1105
# Name: salary, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(6,4))
sns.countplot(data=df, x="marital_status_summary",hue="salary", palette="tab10")
plt.xlabel("marital_status_summary", fontsize=9);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/0JtYnFb/50.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new marital status (married, unmarried) and visualize it with pie plot separately**

# %%
# Your Code is Here

df.groupby("marital_status_summary")["salary"].value_counts(normalize=True)
# Out:
# marital_status_summary  salary
# married                 <=50K    0.563
#                         >50K     0.437
# unmarried               <=50K    0.935
#                         >50K     0.065
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# marital_status_summary  salary
# married                 <=50K    0.563
#                         >50K     0.437
# unmarried               <=50K    0.935
#                         >50K     0.065
# Name: salary, dtype: float64

# %%
# Your Code is Here
percentage_salary_summary = df.groupby("marital_status_summary")["salary"].value_counts(normalize=True)
fig, axs = plt.subplots(1, 2, figsize=(16, 4))  # Genişlik 10 inç, yükseklik 5 inç olarak ayarlandı
mycolors = ['pink' ,'#86C9EB' ]
for i, marr in enumerate(df['marital_status_summary'].unique()[::-1]):
    data = percentage_salary_summary[marr]
    labels = data.index     
    sizes = data.values * 100
    axs[i].set_title(marr, pad=15,fontsize=10)  
    axs[i].pie(sizes, labels=labels, autopct='%1.2f%%', colors=mycolors, startangle=360 ,textprops={'fontsize': 8})    
    axs[i].set_ylabel('salary',fontsize=8) 
    plt.tight_layout()
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/TYxT5Zz/51.png)

# %% [markdown]
# **Check the count of person in each these new marital status (married, unmarried) by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("salary")["marital_status_summary"].value_counts()
# Out:
# salary  marital_status_summary
# <=50K   unmarried                 16021
#         married                    8677
# >50K    married                    6734
#         unmarried                  1105
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  marital_status_summary
# <=50K   unmarried                 16021
#         married                    8677
# >50K    married                    6734
#         unmarried                  1105
# Name: marital_status_summary, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(6,4))
sns.countplot(data=df, x="salary",hue="marital_status_summary" ,palette="tab10");

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/YWjjsZP/52.png)

# %% [markdown]
# **Check the the percentage distribution of person in each these new marital status (married, unmarried) by "salary" levels and visualize it with pie plot separately**

# %%
# Your Code is Here
df.groupby("salary")["marital_status_summary"].value_counts(normalize=True)
# Out:
# salary  marital_status_summary
# <=50K   unmarried                0.649
#         married                  0.351
# >50K    married                  0.859
#         unmarried                0.141
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# salary  marital_status_summary
# <=50K   unmarried                0.649
#         married                  0.351
# >50K    married                  0.859
#         unmarried                0.141
# Name: marital_status_summary, dtype: float64

# %%
my_df = df.groupby('salary')['marital_status_summary'].value_counts(normalize = True).reset_index()
my_df = my_df.rename(columns={'proportion' : "percentage"})
my_df = my_df.sort_values(by = ['salary', 'marital_status_summary'])
my_df
# Out:
#   salary marital_status_summary  percentage
# 1  <=50K                married       0.351
# 0  <=50K              unmarried       0.649
# 2   >50K                married       0.859
# 3   >50K              unmarried       0.141

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Swb4rb7/v53.png)

# %%
# Your Code is Here
percentage_salary_summary = df.groupby("salary")["marital_status_summary"].value_counts(normalize=True)
fig, axs = plt.subplots(1, 2, figsize=(16, 4))  # Genişlik 10 inç, yükseklik 5 inç olarak ayarlandı
mycolors = ['pink','#86C9EB' ]
for i, salary in enumerate(my_df['salary'].unique()):
    data = percentage_salary_summary[salary]
    labels = data.index    
    if i==0:
        mycolors = ['#86C9EB','pink' ]
    else:
        mycolors = ['pink','#86C9EB' ]
    sizes = data.values * 100
    axs[i].set_title(salary, pad=15,fontsize=10)  
    axs[i].pie(sizes, labels=labels, autopct='%1.2f%%', colors=mycolors, startangle=120*(i+1) ,textprops={'fontsize': 8})
    
    axs[i].set_ylabel('percentage',fontsize=8) 
    plt.tight_layout()
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/cJxmqwG/54.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# Result :
# Evli bireylerin çoğunluğu >50K maaş aralığındadır (%85.9), ancak <=50K maaş aralığındaki oranları da önemlidir (%35.1).
# Bekar bireylerin büyük çoğunluğu <=50K maaş aralığındadır (%93.5) ve >50K maaş aralığındaki oranları oldukça düşüktür (%6.5).
#
# Bu veri seti, medeni durumun maaş üzerindeki etkisini değerlendirmek için kullanılabilir.
# Evli bireylerin, genel olarak, daha yüksek maaş aralıklarına sahip olma eğiliminde olduğu görülmektedir,
# ancak bu, bekar bireylerin daha düşük maaş aralıklarında olduğu anlamına gelmez. Bekar maaslari üzerinde baska etkenler de
# olabilir. (örnegin vergi sinifi)

# %% [markdown]
# ### workclass

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here
df["workclass"].value_counts()
# Out:
# workclass
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
# Your Code is Here
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="workclass",palette="tab10")
plt.xticks(rotation=90);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/NmKTp84/55.png)

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
# Replace "?" values with "Unkown"

# Your Code is Here
df['workclass'].replace("?",'Unknown',inplace=True)
df['workclass'].sample(5)
# Out:
# 31694             Private
# 14244             Private
# 23161             Unknown
# 32198    Self-emp-not-inc
# 18661           Local-gov
# Name: workclass, dtype: object

# %% [markdown]
# **Check the count of person in each "salary" levels by workclass groups and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("workclass")["salary"].value_counts()
# Out:
# workclass         salary
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17712
#                   >50K       4961
# Self-emp-inc      >50K        622
#                   <=50K       494
# Self-emp-not-inc  <=50K      1816
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Unknown           <=50K      1645
#                   >50K        191
# Without-pay       <=50K        14
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# workclass         salary
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17712
#                   >50K       4961
# Self-emp-inc      >50K        622
#                   <=50K       494
# Self-emp-not-inc  <=50K      1816
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Unknown           <=50K      1645
#                   >50K        191
# Without-pay       <=50K        14
# Name: salary, dtype: int64

# %%
# Your Code is Here
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="workclass",hue="salary" ,palette="tab10")
plt.xticks(rotation=90)
plt.legend(loc="upper left");

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/bPnNvsn/56.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each workclass groups and visualize it with bar plot**

# %%
# Your Code is Here
df.groupby("workclass")["salary"].value_counts(normalize=True)
# Out:
# workclass         salary
# Federal-gov       <=50K    0.614
#                   >50K     0.386
# Local-gov         <=50K    0.705
#                   >50K     0.295
# Never-worked      <=50K    1.000
# Private           <=50K    0.781
#                   >50K     0.219
# Self-emp-inc      >50K     0.557
#                   <=50K    0.443
# Self-emp-not-inc  <=50K    0.715
#                   >50K     0.285
# State-gov         <=50K    0.728
#                   >50K     0.272
# Unknown           <=50K    0.896
#                   >50K     0.104
# Without-pay       <=50K    1.000
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# workclass         salary
# Federal-gov       <=50K    0.614
#                   >50K     0.386
# Local-gov         <=50K    0.705
#                   >50K     0.295
# Never-worked      <=50K    1.000
# Private           <=50K    0.781
#                   >50K     0.219
# Self-emp-inc      >50K     0.557
#                   <=50K    0.443
# Self-emp-not-inc  <=50K    0.715
#                   >50K     0.285
# State-gov         <=50K    0.728
#                   >50K     0.272
# Unknown           <=50K    0.896
#                   >50K     0.104
# Without-pay       <=50K    1.000
# Name: salary, dtype: float64

# %%
# Your Code is Here

my_df = df.groupby('workclass')['salary'].value_counts(normalize = True).reset_index()
my_df = my_df.rename(columns={'proportion' : "percentage"})
my_df
# Out:
#            workclass salary  percentage
# 0        Federal-gov  <=50K       0.614
# 1        Federal-gov   >50K       0.386
# 2          Local-gov  <=50K       0.705
# 3          Local-gov   >50K       0.295
# 4       Never-worked  <=50K       1.000
# 5            Private  <=50K       0.781
# 6            Private   >50K       0.219
# 7       Self-emp-inc   >50K       0.557
# 8       Self-emp-inc  <=50K       0.443
# 9   Self-emp-not-inc  <=50K       0.715
# 10  Self-emp-not-inc   >50K       0.285
# 11         State-gov  <=50K       0.728
# 12         State-gov   >50K       0.272
# 13           Unknown  <=50K       0.896
# 14           Unknown   >50K       0.104
# 15       Without-pay  <=50K       1.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/8YvM14M/57.png)

# %%
# Your Code is Here

plt.figure(figsize=(6,4))
ax = sns.barplot(data=my_df, x="workclass", y="percentage", hue="salary" , palette="tab10")
plt.xticks(rotation=90)
plt.legend(loc="upper left")
for container in ax.containers:
    ax.bar_label(container,fmt='%1.2f',fontsize=8 );

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/NFN5q04/58.png)

# %% [markdown]
# **Check the count of person in each workclass groups by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("salary")["workclass"].value_counts()
# Out:
# salary  workclass
# <=50K   Private             17712
#         Self-emp-not-inc     1816
#         Unknown              1645
#         Local-gov            1476
#         State-gov             945
#         Federal-gov           589
#         Self-emp-inc          494
#         Without-pay            14
#         Never-worked            7
# >50K    Private              4961
#         Self-emp-not-inc      724
#         Self-emp-inc          622
#         Local-gov             617
#         Federal-gov           371
#         State-gov             353
#         Unknown               191
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  workclass
# <=50K   Private             17712
#         Self-emp-not-inc     1816
#         Unknown              1645
#         Local-gov            1476
#         State-gov             945
#         Federal-gov           589
#         Self-emp-inc          494
#         Without-pay            14
#         Never-worked            7
# >50K    Private              4961
#         Self-emp-not-inc      724
#         Self-emp-inc          622
#         Local-gov             617
#         Federal-gov           371
#         State-gov             353
#         Unknown               191
# Name: workclass, dtype: int64

# %%
# Your Code is Here
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="salary", hue="workclass" , palette="tab10")

plt.legend(loc="upper center");

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/98V8zkN/59.png)

# %% [markdown]
# **Check the the percentage distribution of person in each workclass groups by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("salary")["workclass"].value_counts(normalize=True)
# Out:
# salary  workclass
# <=50K   Private            0.717
#         Self-emp-not-inc   0.074
#         Unknown            0.067
#         Local-gov          0.060
#         State-gov          0.038
#         Federal-gov        0.024
#         Self-emp-inc       0.020
#         Without-pay        0.001
#         Never-worked       0.000
# >50K    Private            0.633
#         Self-emp-not-inc   0.092
#         Self-emp-inc       0.079
#         Local-gov          0.079
#         Federal-gov        0.047
#         State-gov          0.045
#         Unknown            0.024
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# salary  workclass
# <=50K   Private            0.717
#         Self-emp-not-inc   0.074
#         Unknown            0.067
#         Local-gov          0.060
#         State-gov          0.038
#         Federal-gov        0.024
#         Self-emp-inc       0.020
#         Without-pay        0.001
#         Never-worked       0.000
# >50K    Private            0.633
#         Self-emp-not-inc   0.092
#         Self-emp-inc       0.079
#         Local-gov          0.079
#         Federal-gov        0.047
#         State-gov          0.045
#         Unknown            0.024
# Name: workclass, dtype: float64

# %%
# Your Code is Here
my_df = df.groupby('salary')['workclass'].value_counts(normalize = True).reset_index()
my_df = my_df.rename(columns={'proportion' : "percentage"}).sort_values(by=["salary","workclass"])
my_df
# Out:
#    salary         workclass  percentage
# 5   <=50K       Federal-gov       0.024
# 3   <=50K         Local-gov       0.060
# 8   <=50K      Never-worked       0.000
# 0   <=50K           Private       0.717
# 6   <=50K      Self-emp-inc       0.020
# 1   <=50K  Self-emp-not-inc       0.074
# 4   <=50K         State-gov       0.038
# 2   <=50K           Unknown       0.067
# 7   <=50K       Without-pay       0.001
# 13   >50K       Federal-gov       0.047
# 12   >50K         Local-gov       0.079
# 9    >50K           Private       0.633
# 11   >50K      Self-emp-inc       0.079
# 10   >50K  Self-emp-not-inc       0.092
# 14   >50K         State-gov       0.045
# 15   >50K           Unknown       0.024

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/QcdnXpk/60.png)

# %%
# Your Code is Here

plt.figure(figsize=(10,4))
ax = sns.barplot(data=my_df, x="salary",y="percentage", hue="workclass" , palette="tab10")
for container in ax.containers:
    ax.bar_label(container,fmt='%1.3f',fontsize=8 );
plt.legend(loc="upper left", fontsize=8);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Kz5BDBj/61.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# Result :
# Bu veri setine göre:
#
# Özel sektör çalışanlarının hem <=50K hem de >50K maaş aralıklarındaki yüzdesi diğer iş sınıflarına kıyasla oldukça yüksektir.
# Kendi işinin sahibi olanlar ve yerel hükümet çalışanları, hem <=50K hem de >50K maaş aralıklarında önemli yüzdelere sahiptir.
# Federal hükümet çalışanlarının <=50K maaş aralığındaki yüzdesi, >50K maaş aralığındaki yüzdesinden daha düşüktür,
# ancak diğer iş sınıfları için bu böyle değildir.

# %% [markdown]
# ### occupation

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here
df["occupation"].value_counts()
# Out:
# occupation
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
# Your Code is Here
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="occupation" , palette="tab10");
plt.xticks(rotation=90);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/F3qqLjS/62.png)

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
# Replace "?" values with "Unknown"
df["occupation"].replace("?","Unknown", inplace=True)
# Your Code is Here
df["occupation"]
# Out:
# 0             Adm-clerical
# 1          Exec-managerial
# 2        Handlers-cleaners
# 3        Handlers-cleaners
# 4           Prof-specialty
#                ...
# 32532         Tech-support
# 32533    Machine-op-inspct
# 32534         Adm-clerical
# 32535         Adm-clerical
# 32536      Exec-managerial
# Name: occupation, Length: 32537, dtype: object

# %% [markdown]
# **Check the count of person in each "salary" levels by occupation groups and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("occupation")["salary"].value_counts()
# Out:
# occupation         salary
# Adm-clerical       <=50K     3261
#                    >50K       507
# Armed-Forces       <=50K        8
#                    >50K         1
# Craft-repair       <=50K     3165
#                    >50K       929
# Exec-managerial    <=50K     2097
#                    >50K      1968
# Farming-fishing    <=50K      877
#                    >50K       115
# Handlers-cleaners  <=50K     1283
#                    >50K        86
# Machine-op-inspct  <=50K     1751
#                    >50K       249
# Other-service      <=50K     3154
#                    >50K       137
# Priv-house-serv    <=50K      146
#                    >50K         1
# Prof-specialty     <=50K     2278
#                    >50K      1858
# Protective-serv    <=50K      438
#                    >50K       211
# Sales              <=50K     2667
#                    >50K       983
# Tech-support       <=50K      644
#                    >50K       283
# Transport-moving   <=50K     1277
#                    >50K       320
# Unknown            <=50K     1652
#                    >50K       191
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# occupation         salary
# Adm-clerical       <=50K     3261
#                    >50K       507
# Armed-Forces       <=50K        8
#                    >50K         1
# Craft-repair       <=50K     3165
#                    >50K       929
# Exec-managerial    <=50K     2097
#                    >50K      1968
# Farming-fishing    <=50K      877
#                    >50K       115
# Handlers-cleaners  <=50K     1283
#                    >50K        86
# Machine-op-inspct  <=50K     1751
#                    >50K       249
# Other-service      <=50K     3154
#                    >50K       137
# Priv-house-serv    <=50K      146
#                    >50K         1
# Prof-specialty     <=50K     2278
#                    >50K      1858
# Protective-serv    <=50K      438
#                    >50K       211
# Sales              <=50K     2667
#                    >50K       983
# Tech-support       <=50K      644
#                    >50K       283
# Transport-moving   <=50K     1277
#                    >50K       320
# Unknown            <=50K     1652
#                    >50K       191
# Name: salary, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(6,4))
sns.countplot(data=df, x="occupation", hue="salary" , palette="tab10")
plt.xticks(rotation=90)
plt.legend(loc="upper right");

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/RhkhQCW/63.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each occupation groups and visualize it with bar plot**

# %%
# Your Code is Here

df.groupby("occupation")["salary"].value_counts(normalize=True)
# Out:
# occupation         salary
# Adm-clerical       <=50K    0.865
#                    >50K     0.135
# Armed-Forces       <=50K    0.889
#                    >50K     0.111
# Craft-repair       <=50K    0.773
#                    >50K     0.227
# Exec-managerial    <=50K    0.516
#                    >50K     0.484
# Farming-fishing    <=50K    0.884
#                    >50K     0.116
# Handlers-cleaners  <=50K    0.937
#                    >50K     0.063
# Machine-op-inspct  <=50K    0.875
#                    >50K     0.124
# Other-service      <=50K    0.958
#                    >50K     0.042
# Priv-house-serv    <=50K    0.993
#                    >50K     0.007
# Prof-specialty     <=50K    0.551
#                    >50K     0.449
# Protective-serv    <=50K    0.675
#                    >50K     0.325
# Sales              <=50K    0.731
#                    >50K     0.269
# Tech-support       <=50K    0.695
#                    >50K     0.305
# Transport-moving   <=50K    0.800
#                    >50K     0.200
# Unknown            <=50K    0.896
#                    >50K     0.104
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# occupation         salary
# Adm-clerical       <=50K    0.865
#                    >50K     0.135
# Armed-Forces       <=50K    0.889
#                    >50K     0.111
# Craft-repair       <=50K    0.773
#                    >50K     0.227
# Exec-managerial    <=50K    0.516
#                    >50K     0.484
# Farming-fishing    <=50K    0.884
#                    >50K     0.116
# Handlers-cleaners  <=50K    0.937
#                    >50K     0.063
# Machine-op-inspct  <=50K    0.875
#                    >50K     0.124
# Other-service      <=50K    0.958
#                    >50K     0.042
# Priv-house-serv    <=50K    0.993
#                    >50K     0.007
# Prof-specialty     <=50K    0.551
#                    >50K     0.449
# Protective-serv    <=50K    0.675
#                    >50K     0.325
# Sales              <=50K    0.731
#                    >50K     0.269
# Tech-support       <=50K    0.695
#                    >50K     0.305
# Transport-moving   <=50K    0.800
#                    >50K     0.200
# Unknown            <=50K    0.896
#                    >50K     0.104
# Name: salary, dtype: float64

# %%
# Your Code is Here

my_df = df.groupby('occupation')['salary'].value_counts(normalize = True).reset_index()
my_df = my_df.rename(columns={'proportion' : "percentage"})
my_df
# Out:
#            occupation salary  percentage
# 0        Adm-clerical  <=50K       0.865
# 1        Adm-clerical   >50K       0.135
# 2        Armed-Forces  <=50K       0.889
# 3        Armed-Forces   >50K       0.111
# 4        Craft-repair  <=50K       0.773
# 5        Craft-repair   >50K       0.227
# 6     Exec-managerial  <=50K       0.516
# 7     Exec-managerial   >50K       0.484
# 8     Farming-fishing  <=50K       0.884
# 9     Farming-fishing   >50K       0.116
# 10  Handlers-cleaners  <=50K       0.937
# 11  Handlers-cleaners   >50K       0.063
# 12  Machine-op-inspct  <=50K       0.875
# 13  Machine-op-inspct   >50K       0.124
# 14      Other-service  <=50K       0.958
# 15      Other-service   >50K       0.042
# 16    Priv-house-serv  <=50K       0.993
# 17    Priv-house-serv   >50K       0.007
# 18     Prof-specialty  <=50K       0.551
# 19     Prof-specialty   >50K       0.449
# 20    Protective-serv  <=50K       0.675
# 21    Protective-serv   >50K       0.325
# 22              Sales  <=50K       0.731
# 23              Sales   >50K       0.269
# 24       Tech-support  <=50K       0.695
# 25       Tech-support   >50K       0.305
# 26   Transport-moving  <=50K       0.800
# 27   Transport-moving   >50K       0.200
# 28            Unknown  <=50K       0.896
# 29            Unknown   >50K       0.104

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/mb7JS3n/64.png)

# %%
# Your Code is Here

plt.figure(figsize=(10,4))
ax = sns.barplot(data=my_df, x="occupation", y="percentage" , hue="salary", palette="tab10")
for container in ax.containers:
    ax.bar_label(container,fmt='%1.2f',fontsize=8 );
plt.xticks(rotation=90)
plt.legend(loc="upper right");

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/sW2b8wL/65.png)

# %% [markdown]
# **Check the count of person in each occupation groups by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here
df.groupby('salary')['occupation'].value_counts()
# Out:
# salary  occupation
# <=50K   Adm-clerical         3261
#         Craft-repair         3165
#         Other-service        3154
#         Sales                2667
#         Prof-specialty       2278
#         Exec-managerial      2097
#         Machine-op-inspct    1751
#         Unknown              1652
#         Handlers-cleaners    1283
#         Transport-moving     1277
#         Farming-fishing       877
#         Tech-support          644
#         Protective-serv       438
#         Priv-house-serv       146
#         Armed-Forces            8
# >50K    Exec-managerial      1968
#         Prof-specialty       1858
#         Sales                 983
#         Craft-repair          929
#         Adm-clerical          507
#         Transport-moving      320
#         Tech-support          283
#         Machine-op-inspct     249
#         Protective-serv       211
#         Unknown               191
#         Other-service         137
#         Farming-fishing       115
#         Handlers-cleaners      86
#         Armed-Forces            1
#         Priv-house-serv         1
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  occupation
# <=50K   Adm-clerical         3261
#         Craft-repair         3165
#         Other-service        3154
#         Sales                2667
#         Prof-specialty       2278
#         Exec-managerial      2097
#         Machine-op-inspct    1751
#         Unknown              1652
#         Handlers-cleaners    1283
#         Transport-moving     1277
#         Farming-fishing       877
#         Tech-support          644
#         Protective-serv       438
#         Priv-house-serv       146
#         Armed-Forces            8
# >50K    Exec-managerial      1968
#         Prof-specialty       1858
#         Sales                 983
#         Craft-repair          929
#         Adm-clerical          507
#         Transport-moving      320
#         Tech-support          283
#         Machine-op-inspct     249
#         Protective-serv       211
#         Unknown               191
#         Other-service         137
#         Farming-fishing       115
#         Handlers-cleaners      86
#         Armed-Forces            1
#         Priv-house-serv         1
# Name: occupation, dtype: int64

# %%
# Your Code is Here
plt.figure(figsize=(7,4))
sns.countplot(data=df, x="salary", hue="occupation" , palette="tab10")
#plt.xticks(rotation=90)
plt.legend(loc="upper right",fontsize=7);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/cvHS3FH/66.png)

# %% [markdown]
# **Check the the percentage distribution of person in each occupation groups by "salary" levels and visualize it with bar plot**

# %%
# Your Code is Here

df.groupby('salary')['occupation'].value_counts(normalize=True)
# Out:
# salary  occupation
# <=50K   Adm-clerical        0.132
#         Craft-repair        0.128
#         Other-service       0.128
#         Sales               0.108
#         Prof-specialty      0.092
#         Exec-managerial     0.085
#         Machine-op-inspct   0.071
#         Unknown             0.067
#         Handlers-cleaners   0.052
#         Transport-moving    0.052
#         Farming-fishing     0.036
#         Tech-support        0.026
#         Protective-serv     0.018
#         Priv-house-serv     0.006
#         Armed-Forces        0.000
# >50K    Exec-managerial     0.251
#         Prof-specialty      0.237
#         Sales               0.125
#         Craft-repair        0.119
#         Adm-clerical        0.065
#         Transport-moving    0.041
#         Tech-support        0.036
#         Machine-op-inspct   0.032
#         Protective-serv     0.027
#         Unknown             0.024
#         Other-service       0.017
#         Farming-fishing     0.015
#         Handlers-cleaners   0.011
#         Priv-house-serv     0.000
#         Armed-Forces        0.000
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# salary  occupation
# <=50K   Adm-clerical        0.132
#         Craft-repair        0.128
#         Other-service       0.128
#         Sales               0.108
#         Prof-specialty      0.092
#         Exec-managerial     0.085
#         Machine-op-inspct   0.071
#         Unknown             0.067
#         Handlers-cleaners   0.052
#         Transport-moving    0.052
#         Farming-fishing     0.036
#         Tech-support        0.026
#         Protective-serv     0.018
#         Priv-house-serv     0.006
#         Armed-Forces        0.000
# >50K    Exec-managerial     0.251
#         Prof-specialty      0.237
#         Sales               0.125
#         Craft-repair        0.119
#         Adm-clerical        0.065
#         Transport-moving    0.041
#         Tech-support        0.036
#         Machine-op-inspct   0.032
#         Protective-serv     0.027
#         Unknown             0.024
#         Other-service       0.017
#         Farming-fishing     0.015
#         Handlers-cleaners   0.011
#         Armed-Forces        0.000
#         Priv-house-serv     0.000
# Name: occupation, dtype: float64

# %%
# Your Code is Here
my_df = df.groupby('salary')['occupation'].value_counts(normalize = True).reset_index()
my_df = my_df.rename(columns={'proportion' : "percentage"}).sort_values(by=["salary","occupation"])
my_df
# Out:
#    salary         occupation  percentage
# 0   <=50K       Adm-clerical       0.132
# 14  <=50K       Armed-Forces       0.000
# 1   <=50K       Craft-repair       0.128
# 5   <=50K    Exec-managerial       0.085
# 10  <=50K    Farming-fishing       0.036
# 8   <=50K  Handlers-cleaners       0.052
# 6   <=50K  Machine-op-inspct       0.071
# 2   <=50K      Other-service       0.128
# 13  <=50K    Priv-house-serv       0.006
# 4   <=50K     Prof-specialty       0.092
# 12  <=50K    Protective-serv       0.018
# 3   <=50K              Sales       0.108
# 11  <=50K       Tech-support       0.026
# 9   <=50K   Transport-moving       0.052
# 7   <=50K            Unknown       0.067
# 19   >50K       Adm-clerical       0.065
# 29   >50K       Armed-Forces       0.000
# 18   >50K       Craft-repair       0.119
# 15   >50K    Exec-managerial       0.251
# 26   >50K    Farming-fishing       0.015
# 27   >50K  Handlers-cleaners       0.011
# 22   >50K  Machine-op-inspct       0.032
# 25   >50K      Other-service       0.017
# 28   >50K    Priv-house-serv       0.000
# 16   >50K     Prof-specialty       0.237
# 23   >50K    Protective-serv       0.027
# 17   >50K              Sales       0.125
# 21   >50K       Tech-support       0.036
# 20   >50K   Transport-moving       0.041
# 24   >50K            Unknown       0.024

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/7tK0PqX/67.png)

# %%
# Your Code is Here

plt.figure(figsize=(12,4))
ax = sns.barplot(data=my_df, x="salary",y="percentage", hue="occupation" , palette="tab10")
for container in ax.containers:
    ax.bar_label(container,fmt='%1.3f',fontsize=7 );
plt.legend(loc="upper right", fontsize=6);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/7brj34F/68.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# Result :
#     Bu veri seti, mesleklerin maaş aralıklarındaki dağılımını göstermektedir.
#     Bazı mesleklerde <=50K maaş aralığındaki bireylerin oranı yüksekken, diğerlerinde bu oran düşüktür.
#     Aynı şekilde, >50K maaş aralığındaki bireylerin oranı da mesleklere göre değişkenlik göstermektedir.
#     Özellikle, yöneticilik (Exec-managerial) ve profesyonel uzmanlık (Prof-specialty) gibi mesleklerde >50K maaş
#     aralığında çalışanların oranı yüksektir.

# %% [markdown]
# ### race

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here

df["race"].value_counts()
# Out:
# race
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(6,4))
ax = sns.countplot(data=df, x="race", palette="tab10")
plt.xticks(rotation=45);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/LdKct3G/69.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by races and visualize it with countplot**

# %%
# Your Code is Here

df.groupby('race')['salary'].value_counts()
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K       275
#                     >50K         36
# Asian-Pac-Islander  <=50K       762
#                     >50K        276
# Black               <=50K      2735
#                     >50K        387
# Other               <=50K       246
#                     >50K         25
# White               <=50K     20680
#                     >50K       7115
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# race                salary
# Amer-Indian-Eskimo  <=50K       275
#                     >50K         36
# Asian-Pac-Islander  <=50K       762
#                     >50K        276
# Black               <=50K      2735
#                     >50K        387
# Other               <=50K       246
#                     >50K         25
# White               <=50K     20680
#                     >50K       7115
# Name: salary, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(6,4))
ax = sns.countplot(data=df, x="race", hue="salary", palette="tab10")
plt.xticks(rotation=45);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Qb4n8Y5/70.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each races and visualize it with pie plot**

# %%
# Your Code is Here

df.groupby('race')['salary'].value_counts(normalize=True)
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K    0.884
#                     >50K     0.116
# Asian-Pac-Islander  <=50K    0.734
#                     >50K     0.266
# Black               <=50K    0.876
#                     >50K     0.124
# Other               <=50K    0.908
#                     >50K     0.092
# White               <=50K    0.744
#                     >50K     0.256
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# race                salary
# Amer-Indian-Eskimo  <=50K    0.884
#                     >50K     0.116
# Asian-Pac-Islander  <=50K    0.734
#                     >50K     0.266
# Black               <=50K    0.876
#                     >50K     0.124
# Other               <=50K    0.908
#                     >50K     0.092
# White               <=50K    0.744
#                     >50K     0.256
# Name: salary, dtype: float64

# %%
# Your Code is Here

percentage = df.groupby('race')['salary'].value_counts(normalize=True)
races = df.race.value_counts().index.sort_values()
fig, axs = plt.subplots(2, 3, figsize=(10, 5))
mycolors = ['pink', '#86C9EB']
for i, race in enumerate(races):
    row = i // 3
    col = i % 3
    data= percentage[race]
    sizes = data.values*100
    labels = data.index
    axs[row, col].pie(sizes, labels=labels, autopct='%1.2f%%', colors=mycolors, startangle=360, textprops={'fontsize': 10})
    axs[row, col].set_title(race, fontsize = 10)
    axs[row, col].axis('equal')
    axs[row, col].set_ylabel('salary', fontsize = 10)
fig.delaxes(axs[1, 2])
plt.tight_layout()
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/xsJWXp4/71.png)

# %% [markdown]
# **Check the count of person in each races by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.groupby('salary')['race'].value_counts()
# Out:
# salary  race
# <=50K   White                 20680
#         Black                  2735
#         Asian-Pac-Islander      762
#         Amer-Indian-Eskimo      275
#         Other                   246
# >50K    White                  7115
#         Black                   387
#         Asian-Pac-Islander      276
#         Amer-Indian-Eskimo       36
#         Other                    25
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  race
# <=50K   White                 20680
#         Black                  2735
#         Asian-Pac-Islander      762
#         Amer-Indian-Eskimo      275
#         Other                   246
# >50K    White                  7115
#         Black                   387
#         Asian-Pac-Islander      276
#         Amer-Indian-Eskimo       36
#         Other                    25
# Name: race, dtype: int64

# %%
# Your Code is Here
plt.figure(figsize=(6,4))
ax = sns.countplot(data=df, x="salary", hue="race", palette="tab10")
#plt.xticks(rotation=45);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/RBpPR38/72.png)

# %% [markdown]
# **Check the the percentage distribution of person in each races by "salary" levels and visualize it with bar plot**

# %%
# Your Code is Here

df.groupby('salary')['race'].value_counts(normalize=True)
# Out:
# salary  race
# <=50K   White                0.837
#         Black                0.111
#         Asian-Pac-Islander   0.031
#         Amer-Indian-Eskimo   0.011
#         Other                0.010
# >50K    White                0.908
#         Black                0.049
#         Asian-Pac-Islander   0.035
#         Amer-Indian-Eskimo   0.005
#         Other                0.003
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# salary  race
# <=50K   White                0.837
#         Black                0.111
#         Asian-Pac-Islander   0.031
#         Amer-Indian-Eskimo   0.011
#         Other                0.010
# >50K    White                0.908
#         Black                0.049
#         Asian-Pac-Islander   0.035
#         Amer-Indian-Eskimo   0.005
#         Other                0.003
# Name: race, dtype: float64

# %%
# Your Code is Here

my_df = df.groupby('salary')['race'].value_counts(normalize = True).reset_index()
my_df = my_df.rename(columns={'proportion' : "percentage"}).sort_values(by=["salary","race"])
my_df
# Out:
#   salary                race  percentage
# 3  <=50K  Amer-Indian-Eskimo       0.011
# 2  <=50K  Asian-Pac-Islander       0.031
# 1  <=50K               Black       0.111
# 4  <=50K               Other       0.010
# 0  <=50K               White       0.837
# 8   >50K  Amer-Indian-Eskimo       0.005
# 7   >50K  Asian-Pac-Islander       0.035
# 6   >50K               Black       0.049
# 9   >50K               Other       0.003
# 5   >50K               White       0.908

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Xy9sYCY/73.png)

# %%
# Your Code is Here
plt.figure(figsize=(10,4))
ax = sns.barplot(data=my_df, x="salary",y="percentage", hue="race" , palette="tab10")
for container in ax.containers:
    ax.bar_label(container,fmt='%1.3f',fontsize=7 );
plt.legend(loc="upper left", fontsize=6);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/X8kf9NZ/74.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# Result :
# Bu veri seti, ırk çeşitliliğini yansıtmakta olup, çoğunlukla Beyaz ve Siyah ırklarının belirgin olduğunu göstermektedir.
# Ancak, diğer ırklar da temsil edilmektedir.
#
# 1. Beyaz bireyler, hem <=50K maaş aralığında hem de >50K maaş aralığında çoğunluğu oluşturur.
# Özellikle, >50K maaş aralığında beyaz bireylerin oranı oldukça yüksektir (%90.8).
#
# 2. Siyah bireylerin, hem <=50K maaş aralığında hem de >50K maaş aralığında belirgin bir varlığı vardır,
# ancak beyaz bireylere kıyasla daha düşük oranlarda bulunurlar.
#
# 3. Asyalı-Pasifik Adalı ve Amerikan Yerlisi-Eskimo bireyler, hem <=50K maaş aralığında hem de >50K maaş aralığında
# daha küçük oranlarda temsil edilir.
#
# 4. "Diğer" ırk kategorisine mensup bireyler, her iki maaş aralığında da en az temsil edilen gruptur

# %% [markdown]
# ### gender

# %% [markdown]
# **Check the count of person in each gender and visualize it with countplot**

# %%
df.rename(columns={'sex': 'gender'}, inplace=True)
df.head(1)
# Out:
#    age  workclass  fnlwgt  education  education_num marital_status  \
# 0   39  State-gov   77516  Bachelors         13.000  Never-married
#
#      occupation   relationship   race gender  capital_gain  capital_loss  \
# 0  Adm-clerical  Not-in-family  White   Male          2174             0
#
#    hours_per_week native_country salary education_summary  \
# 0              40  United-States  <=50K  high_level_grade
#
#   marital_status_summary
# 0              unmarried

# %%
# Your Code is Here

df["gender"].value_counts()
# Out:
# gender
# Male      21775
# Female    10762
# Name: count, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(6,4))
ax = sns.countplot(data=df, x="gender", palette="tab10")
#plt.xticks(rotation=45);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/GVTRbrb/75.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by gender and visualize it with countplot**

# %%
# Your Code is Here


df.groupby('gender')['salary'].value_counts()
# Out:
# gender  salary
# Female  <=50K      9583
#         >50K       1179
# Male    <=50K     15115
#         >50K       6660
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# gender  salary
# Female  <=50K      9583
#         >50K       1179
# Male    <=50K     15115
#         >50K       6660
# Name: salary, dtype: int64

# %%
# Your Code is Here
plt.figure(figsize=(6,4))
ax = sns.countplot(data=df, x="gender",hue="salary", palette="tab10")
#plt.xticks(rotation=45);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Nr8HRPk/76.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each gender and visualize it with pie plot**

# %%
# Your Code is Here


df.groupby('gender')['salary'].value_counts(normalize=True)
# Out:
# gender  salary
# Female  <=50K    0.890
#         >50K     0.110
# Male    <=50K    0.694
#         >50K     0.306
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# gender  salary
# Female  <=50K    0.890
#         >50K     0.110
# Male    <=50K    0.694
#         >50K     0.306
# Name: salary, dtype: float64

# %%
# Your Code is Here
percentage_gender = df.groupby("gender")["salary"].value_counts(normalize=True)
fig, axs = plt.subplots(1, 2, figsize=(16, 4))  # Genişlik 10 inç, yükseklik 5 inç olarak ayarlandı
mycolors = ['pink','#86C9EB' ]
for i, gender in enumerate(df['gender'].unique()[::-1]):
    data = percentage_gender[gender]
    labels = data.index    
    sizes = data.values * 100
    axs[i].set_title(gender, pad=15,fontsize=10)  
    axs[i].pie(sizes, labels=labels, autopct='%1.2f%%', colors=mycolors, startangle=360 ,textprops={'fontsize': 8})
    
    axs[i].set_ylabel('salary',fontsize=8) 
    plt.tight_layout()
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/nrHj2jk/77.png)

# %% [markdown]
# **Check the count of person in each gender by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("salary")["gender"].value_counts()
# Out:
# salary  gender
# <=50K   Male      15115
#         Female     9583
# >50K    Male       6660
#         Female     1179
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  gender
# <=50K   Male      15115
#         Female     9583
# >50K    Male       6660
#         Female     1179
# Name: gender, dtype: int64

# %%
# Your Code is Here
plt.figure(figsize=(6,4))
ax = sns.countplot(data=df, x="salary",hue="gender", palette="tab10")
#plt.xticks(rotation=45);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/9sfsw11/78.png)

# %% [markdown]
# **Check the the percentage distribution of person in each gender by "salary" levels and visualize it with pie plot**

# %%
# Your Code is Here

df.groupby("salary")["gender"].value_counts(normalize=True)
# Out:
# salary  gender
# <=50K   Male     0.612
#         Female   0.388
# >50K    Male     0.850
#         Female   0.150
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# salary  gender
# <=50K   Male     0.612
#         Female   0.388
# >50K    Male     0.850
#         Female   0.150
# Name: gender, dtype: float64

# %%
# Your Code is Here
percentage_gender = df.groupby("salary")["gender"].value_counts(normalize=True)
fig, axs = plt.subplots(1, 2, figsize=(16, 4))  # Genişlik 10 inç, yükseklik 5 inç olarak ayarlandı
mycolors = ['pink','#86C9EB' ]
for i, salary in enumerate(df['salary'].unique()):
    data = percentage_gender[salary]
    labels = data.index    
    sizes = data.values * 100
    axs[i].set_title(salary, pad=15,fontsize=10)  
    axs[i].pie(sizes, labels=labels, autopct='%1.2f%%', colors=mycolors, startangle=360 ,textprops={'fontsize': 8})
    
    axs[i].set_ylabel('gender',fontsize=8) 
    plt.tight_layout()
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/0DzhNgG/79.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# Result :
# Veri setinde daha fazla erkek (%66) bulunmaktadır.
# Kadınlar genellikle daha düşük maaş aralığında (%89) bulunurken, erkeklerin %30'u daha yüksek maaş aralığında yer almaktadır.
# Erkeklerin yaklasik olarak %61 i 50K'dan daha düsük maas alirken; kadinlarin %85'i 50K'dan daha düsük maas almistir.
# Cinsiyetin maas üzerine etkisini söyleyebiliriz.

# %% [markdown]
# ### native_country

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here

df["native_country"].value_counts()
# Out:
# native_country
# United-States                 29153
# Mexico                          639
# ?                               582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# France                           29
# Greece                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Cambodia                         19
# Trinadad&Tobago                  19
# Laos                             18
# Thailand                         18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Honduras                         13
# Hungary                          13
# Scotland                         12
# Holand-Netherlands                1
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# United-States                 29153
# Mexico                          639
# ?                               582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# France                           29
# Greece                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Cambodia                         19
# Trinadad&Tobago                  19
# Laos                             18
# Thailand                         18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Honduras                         13
# Hungary                          13
# Scotland                         12
# Holand-Netherlands                1
# Name: native_country, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(10,4))
ax = sns.countplot(data=df, x="native_country", palette="tab10")
plt.xticks(rotation=90);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/x3TNT7B/80.png)

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
# Replace "?" values with "Unknown"

# Your Code is Here
df.replace("?", "Unknown", inplace=True)
df["native_country"].value_counts()
# Out:
# native_country
# United-States                 29153
# Mexico                          639
# Unknown                         582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# France                           29
# Greece                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Cambodia                         19
# Trinadad&Tobago                  19
# Laos                             18
# Thailand                         18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Honduras                         13
# Hungary                          13
# Scotland                         12
# Holand-Netherlands                1
# Name: count, dtype: int64

# %% [markdown]
# **Decrease the number of categories in "native_country" feature as US, and Others and create a new feature with this new categorical data**

# %%
def mapping_native_country(x):
    if x == "United-States":
        return "US"
    else:
        return "Others"

# %%
# Your Code is Here
df['native_country'].apply(mapping_native_country).value_counts()
# Out:
# native_country
# US        29153
# Others     3384
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# US        29153
# Others     3384
# Name: native_country, dtype: int64

# %%
# By using "mapping_native_country" def function above, create a new column named "native_country_summary"

# Your Code is Here

df['native_country_summary'] = df['native_country'].apply(mapping_native_country)
df['native_country_summary'].value_counts()
# Out:
# native_country_summary
# US        29153
# Others     3384
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# 0            US
# 1            US
# 2            US
# 3            US
# 4        Others
#           ...
# 32556        US
# 32557        US
# 32558        US
# 32559        US
# 32560        US
# Name: native_country_summary, Length: 32537, dtype: object

# %% [markdown]
# **Visualize the count of person in each new categories (US, Others)**

# %%
# Your Code is Here
plt.figure(figsize=(6,4))
ax = sns.countplot(data=df, x="native_country_summary", palette="tab10")
#plt.xticks(rotation=90);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/wwDhVGd/81.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by these new native countries (US, Others) and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("native_country_summary")["salary"].value_counts()
# Out:
# native_country_summary  salary
# Others                  <=50K      2714
#                         >50K        670
# US                      <=50K     21984
#                         >50K       7169
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# native_country_summary  salary
# Others                  <=50K      2714
#                         >50K        670
# US                      <=50K     21984
#                         >50K       7169
# Name: salary, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(6,4))
ax = sns.countplot(data=df, x="native_country_summary",hue="salary",  palette="tab10")
#plt.xticks(rotation=90);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/SVnKp4k/82.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new native countries (US, Others) and visualize it with pie plot separately**

# %%
# Your Code is Here
df.groupby("native_country_summary")["salary"].value_counts(normalize=True)
# Out:
# native_country_summary  salary
# Others                  <=50K    0.802
#                         >50K     0.198
# US                      <=50K    0.754
#                         >50K     0.246
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# native_country_summary  salary
# Others                  <=50K    0.802
#                         >50K     0.198
# US                      <=50K    0.754
#                         >50K     0.246
# Name: salary, dtype: float64

# %%
# Your Code is Here

percentage_native = df.groupby("native_country_summary")["salary"].value_counts(normalize=True)
fig, axs = plt.subplots(1, 2, figsize=(16, 4))  # Genişlik 10 inç, yükseklik 5 inç olarak ayarlandı
mycolors = ['pink','#86C9EB' ]
for i, native in enumerate(df['native_country_summary'].unique()[::-1]):
    data = percentage_native[native]
    labels = data.index    
    sizes = data.values * 100
    axs[i].set_title(native, pad=15,fontsize=10)  
    axs[i].pie(sizes, labels=labels, autopct='%1.2f%%', colors=mycolors, startangle=360 ,textprops={'fontsize': 8})
    
    axs[i].set_ylabel('salary',fontsize=8) 
    plt.tight_layout()
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/4NQ5b1b/83.png)

# %% [markdown]
# **Check the count of person in each these new native countries (US, Others) by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("salary")["native_country_summary"].value_counts()
# Out:
# salary  native_country_summary
# <=50K   US                        21984
#         Others                     2714
# >50K    US                         7169
#         Others                      670
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  native_country_summary
# <=50K   US                        21984
#         Others                     2714
# >50K    US                         7169
#         Others                      670
# Name: native_country_summary, dtype: int64

# %%
# Your Code is Here


plt.figure(figsize=(6,4))
ax = sns.countplot(data=df, x="salary",hue="native_country_summary",  palette="tab10")
#plt.xticks(rotation=90);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/c1gQfcg/84.png)

# %% [markdown]
# **Check the the percentage distribution of person in each these new native countries (US, Others) by "salary" levels and visualize it with pie plot separately**

# %%
# Your Code is Here

df.groupby("salary")["native_country_summary"].value_counts(normalize=True)
# Out:
# salary  native_country_summary
# <=50K   US                       0.890
#         Others                   0.110
# >50K    US                       0.915
#         Others                   0.085
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# salary  native_country_summary
# <=50K   US                       0.890
#         Others                   0.110
# >50K    US                       0.915
#         Others                   0.085
# Name: native_country_summary, dtype: float64

# %%
# Your Code is Here
percentage_native = df.groupby("salary")["native_country_summary"].value_counts(normalize=True)
fig, axs = plt.subplots(1, 2, figsize=(16, 4))  # Genişlik 10 inç, yükseklik 5 inç olarak ayarlandı
mycolors = ['pink','#86C9EB' ]
for i, salary in enumerate(df['salary'].unique()):
    data = percentage_native[salary]
    labels = data.index    
    sizes = data.values * 100
    axs[i].set_title(salary, pad=15,fontsize=10)  
    axs[i].pie(sizes, labels=labels, autopct='%1.2f%%', colors=mycolors, startangle=360 ,textprops={'fontsize': 8})
    
    axs[i].set_ylabel('native_country_summary',fontsize=8) 
    plt.tight_layout()
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/QHc8m0x/85.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** .................
#     Bu verilere göre:
#
# 1. Amerika Birleşik Devletleri'nde doğmuş bireylerin, diğer ülkelerde doğmuş bireylere kıyasla daha yüksek bir oranda
#     (>50K maaş aralığında %24.6) yüksek maaş aralığında bulunduğu görülmektedir.
#
# 2. Diğer ülkelerde doğmuş bireylerin çoğunluğu (%80.2), Amerika Birleşik Devletleri'ndedoğmuş bireylere kıyasla daha
#     düşük bir maaş aralığında yer almaktadır (<=50K maaş aralığında %80.2).

# %% [markdown]
# <a id="5"></a>
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;">Other Specific Analysis Questions</p>
#
# <a href="#content" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## Analysis Questions

# %% [markdown]
# ### What is the average age of males and females by income level?

# %%
# Your Code is Here
my_age = df.groupby(["salary","gender"])["age"].mean()
my_age
# Out:
# salary  gender
# <=50K   Female   36.217
#         Male     37.149
# >50K    Female   42.126
#         Male     44.627
# Name: age, dtype: float64

# %% [raw]
# Desired Output:
#
# salary  gender
# <=50K   Female   36.217
#         Male     37.149
# >50K    Female   42.126
#         Male     44.627
# Name: age, dtype: float64

# %%
my_age.reset_index()
# Out:
#   salary  gender    age
# 0  <=50K  Female 36.217
# 1  <=50K    Male 37.149
# 2   >50K  Female 42.126
# 3   >50K    Male 44.627

# %%
my_age.index = ["(" + my_age.index[i][0] + ', ' + my_age.index[i][1] + ")" for i in range(len(my_age))]
my_age.index
# Out:
# Index(['(<=50K, Female)', '(<=50K, Male)', '(>50K, Female)', '(>50K, Male)'], dtype='object')

# %%
my_age
# Out:
# (<=50K, Female)   36.217
# (<=50K, Male)     37.149
# (>50K, Female)    42.126
# (>50K, Male)      44.627
# Name: age, dtype: float64

# %%
# Your Code is Here
plt.figure(figsize=(6,4))
sns.set_style('whitegrid')
ax = sns.barplot(x=my_age.index, y=my_age.values, width=0.4)
for container in ax.containers:
    ax.bar_label(container,fmt='%1.2f',fontsize=7 )
ax.grid(axis='x', linewidth=0.5, color='gray')
plt.xlabel("salary, gender");
plt.ylabel("");
plt.xticks(rotation=90);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/BBDy081/86.png)

# %%
# Your Code is Here

my_bar = df.groupby(["salary","gender"])[["age"]].mean().reset_index()
my_bar
# Out:
#   salary  gender    age
# 0  <=50K  Female 36.217
# 1  <=50K    Male 37.149
# 2   >50K  Female 42.126
# 3   >50K    Male 44.627

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/4PD1208/87.png)

# %%
# Your Code is Here

plt.figure(figsize=(6,4))
ax = sns.barplot(data=my_bar, x="salary", y="age",hue="gender",  palette="tab10")
for container in ax.containers:
    ax.bar_label(container,fmt='%1.2f',fontsize=7 );
#plt.xticks(rotation=90);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/2n0yGt7/88.png)

# %% [markdown]
# ### What is the workclass percentages of Americans in high-level income group?

# %%
# Your Code is Here

high_income_americans = df[(df['native_country_summary'] == 'US') & (df['salary'] == '>50K')]
workclass_percentages = high_income_americans['workclass'].value_counts(normalize=True) * 100
workclass_percentages
# Out:
# workclass
# Private            63.314
# Self-emp-not-inc    9.192
# Local-gov           8.021
# Self-emp-inc        7.784
# Federal-gov         4.687
# State-gov           4.547
# Unknown             2.455
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# Private            63.314
# Self-emp-not-inc    9.192
# Local-gov           8.021
# Self-emp-inc        7.784
# Federal-gov         4.687
# State-gov           4.547
# Unknown             2.455
# Name: workclass, dtype: float64

# %%
plt.figure(figsize=(6,4))
g = sns.catplot( x=workclass_percentages.index, y=workclass_percentages.values, kind='bar', palette='tab10', height=4, aspect=1.5)
for ax in g.axes.flat:
    for p in ax.patches:
        ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points', fontsize=7)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/gMHzLgH/89.png)

# %% [markdown]
# ### What is the occupation percentages of Americans who work as "Private" workclass in high-level income group?

# %%
# Your Code is Here
high_income_private = df[(df['native_country_summary'] == 'US') & (df['salary'] == '>50K') & (df['workclass'] == 'Private')]

# Calculate the occupation percentages
occupation_percentages = high_income_private['occupation'].value_counts(normalize=True) * 100
occupation_percentages
# Out:
# occupation
# Exec-managerial     26.438
# Prof-specialty      19.476
# Craft-repair        14.695
# Sales               14.475
# Adm-clerical         6.389
# Transport-moving     5.442
# Tech-support         4.428
# Machine-op-inspct    4.428
# Other-service        1.674
# Handlers-cleaners    1.344
# Farming-fishing      0.595
# Protective-serv      0.595
# Priv-house-serv      0.022
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# Exec-managerial     26.438
# Prof-specialty      19.476
# Craft-repair        14.695
# Sales               14.475
# Adm-clerical         6.389
# Transport-moving     5.442
# Tech-support         4.428
# Machine-op-inspct    4.428
# Other-service        1.674
# Handlers-cleaners    1.344
# Farming-fishing      0.595
# Protective-serv      0.595
# Priv-house-serv      0.022
# Name: occupation, dtype: float64

# %%
# Your Code is Here

plt.figure(figsize=(6,4))
ax = sns.barplot(x=occupation_percentages.index, y=occupation_percentages.values,  palette="tab10")
for container in ax.containers:
    ax.bar_label(container,fmt='%1.2f',fontsize=7 )
plt.xlabel("")
plt.xticks(rotation=90);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/s3Kd7VS/90.png)

# %% [markdown]
# ### What is the education level percentages of Asian-Pac-Islander race group in high-level income group?

# %%
# Your Code is Here
high_income_asian = df[(df['race'] == 'Asian-Pac-Islander') & (df['salary'] == '>50K')]

# Calculate the education level percentages
education_level_percentages = high_income_asian['education'].value_counts(normalize=True) * 100
education_level_percentages
# Out:
# education
# Bachelors      35.145
# Masters        15.580
# HS-grad        12.319
# Some-college   11.957
# Prof-school     9.783
# Doctorate       6.522
# Assoc-voc       3.261
# Assoc-acdm      2.899
# 5th-6th         1.087
# 9th             0.362
# 11th            0.362
# 10th            0.362
# 12th            0.362
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# Bachelors      35.145
# Masters        15.580
# HS-grad        12.319
# Some-college   11.957
# Prof-school     9.783
# Doctorate       6.522
# Assoc-voc       3.261
# Assoc-acdm      2.899
# 5th-6th         1.087
# 9th             0.362
# 11th            0.362
# 10th            0.362
# 12th            0.362
# Name: education, dtype: float64

# %%
# Your Code is Here

plt.figure(figsize=(6,4))
ax = sns.barplot(x=education_level_percentages.index, y=education_level_percentages.values,  palette="tab10")
for container in ax.containers:
    ax.bar_label(container,fmt='%1.2f',fontsize=7 )
plt.xlabel("")
plt.xticks(rotation=90);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/rZnSFBX/91.png)

# %% [markdown]
# ### What is the occupation percentages of Asian-Pac-Islander race group who has a Bachelors degree in high-level income group?

# %%
# Your Code is Here
high_income_asian_bachelors = df[(df['race'] == 'Asian-Pac-Islander') & (df['salary'] == '>50K') & (df['education'] == 'Bachelors')]

# Calculate the occupation percentages
occupation_percentages = high_income_asian_bachelors['occupation'].value_counts(normalize=True) * 100

occupation_percentages
# Out:
# occupation
# Exec-managerial     27.835
# Prof-specialty      25.773
# Adm-clerical        12.371
# Sales                9.278
# Other-service        9.278
# Craft-repair         7.216
# Tech-support         3.093
# Protective-serv      2.062
# Transport-moving     1.031
# Machine-op-inspct    1.031
# Farming-fishing      1.031
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# Exec-managerial     27.835
# Prof-specialty      25.773
# Adm-clerical        12.371
# Sales                9.278
# Other-service        9.278
# Craft-repair         7.216
# Tech-support         3.093
# Protective-serv      2.062
# Transport-moving     1.031
# Machine-op-inspct    1.031
# Farming-fishing      1.031
# Name: occupation, dtype: float64

# %%
# Your Code is Here
plt.figure(figsize=(6,4))
ax = sns.barplot(x=occupation_percentages.index, y=occupation_percentages.values,  palette="tab10")
for container in ax.containers:
    ax.bar_label(container,fmt='%1.2f',fontsize=7 )
plt.xlabel("")
plt.xticks(rotation=90);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/zZVsbJf/92.png)

# %% [markdown]
# ### What is the mean of working hours per week by gender for education level, workclass and marital status? Try to plot all required in one figure.

# %%
# Your Code is Here
mean_working_hours = df.groupby(['gender', 'education_summary', 'native_country_summary', 'marital_status_summary'])['hours_per_week'].mean()
mean_working_hours = mean_working_hours.reset_index()
mean_working_hours
# Out:
#     gender   education_summary native_country_summary marital_status_summary  \
# 0   Female    high_level_grade                 Others                married
# 1   Female    high_level_grade                 Others              unmarried
# 2   Female    high_level_grade                     US                married
# 3   Female    high_level_grade                     US              unmarried
# 4   Female     low_level_grade                 Others                married
# 5   Female     low_level_grade                 Others              unmarried
# 6   Female     low_level_grade                     US                married
# 7   Female     low_level_grade                     US              unmarried
# 8   Female  medium_level_grade                 Others                married
# 9   Female  medium_level_grade                 Others              unmarried
# 10  Female  medium_level_grade                     US                married
# 11  Female  medium_level_grade                     US              unmarried
# 12    Male    high_level_grade                 Others                married
# 13    Male    high_level_grade                 Others              unmarried
# 14    Male    high_level_grade                     US                married
# 15    Male    high_level_grade                     US              unmarried
# 16    Male     low_level_grade                 Others                married
# 17    Male     low_level_grade                 Others              unmarried
# 18    Male     low_level_grade                     US                married
# 19    Male     low_level_grade                     US              unmarried
# 20    Male  medium_level_grade                 Others                married
# 21    Male  medium_level_grade                 Others              unmarried
# 22    Male  medium_level_grade                     US                married
# 23    Male  medium_level_grade                     US              unmarried
#
#     hours_per_week
# 0           39.127
# 1           40.155
# 2           38.478
# 3           40.784
# 4           36.628
# 5           35.651
# 6           37.256
# 7           30.556
# 8           36.574
# 9           36.495
# 10          35.761
# 11          35.903
# 12          44.116
# 13          41.374
# 14          45.740
# 15          43.000
# 16          41.786
# 17          38.556
# 18          41.352
# 19          34.718
# 20          43.203
# 21          39.348
# 22          43.912
# 23          39.857

# %%
df.head(1)
# Out:
#    age  workclass  fnlwgt  education  education_num marital_status  \
# 0   39  State-gov   77516  Bachelors         13.000  Never-married
#
#      occupation   relationship   race gender  capital_gain  capital_loss  \
# 0  Adm-clerical  Not-in-family  White   Male          2174             0
#
#    hours_per_week native_country salary education_summary  \
# 0              40  United-States  <=50K  high_level_grade
#
#   marital_status_summary native_country_summary
# 0              unmarried                     US

# %%
plt.figure(figsize=(6,6))
mycolors = ['pink','#86C9EB']
sns.set_style('whitegrid')
plt.subplots_adjust(top=0.9)
plot = sns.catplot(data = df, x="education_summary",y="hours_per_week",hue="gender" , kind="bar", col="marital_status_summary",
            row="native_country_summary", palette=mycolors, errorbar=None, legend_out=True, aspect=1.6, native_scale=True,
            height=4  
           )

for ax in plot.axes.flat:
    for p in ax.patches:
        ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha='center', va='center', xytext=(0, 5), textcoords='offset points')
plt.subplots_adjust(top=0.9)
plt.suptitle("Working Hours Per Week by Gender for Education, Native Country, Marital Status", fontsize=12,y=1)
plt.tight_layout()
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/G5KY8nf/93.png)

# %% [markdown]
# <a id="6"></a>
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;">Dropping Similar & Unneccessary Features</p>
#
# <a href="#content" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# Your Code is Here

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32537 entries, 0 to 32536
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32537 non-null  int64
#  1   workclass               32537 non-null  object
#  2   fnlwgt                  32537 non-null  int64
#  3   education               32537 non-null  object
#  4   education_num           31735 non-null  float64
#  5   marital_status          32537 non-null  object
#  6   occupation              32537 non-null  object
#  7   relationship            32537 non-null  object
#  8   race                    32537 non-null  object
#  9   gender                  32537 non-null  object
#  10  capital_gain            32537 non-null  int64
#  11  capital_loss            32537 non-null  int64
#  12  hours_per_week          32537 non-null  int64
#  13  native_country          32537 non-null  object
#  14  salary                  32537 non-null  object
#  15  education_summary       32537 non-null  object
#  16  marital_status_summary  32537 non-null  object
#  17  native_country_summary  32537 non-null  object
# dtypes: float64(1), int64(5), object(12)
# memory usage: 4.5+ MB

# %% [raw]
# Desired Output:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32537 non-null  int64
#  1   workclass               32537 non-null  object
#  2   fnlwgt                  32537 non-null  int64
#  3   education               32537 non-null  object
#  4   education_num           31735 non-null  float64
#  5   marital_status          32537 non-null  object
#  6   occupation              32537 non-null  object
#  7   relationship            32537 non-null  object
#  8   race                    32537 non-null  object
#  9   gender                  32537 non-null  object
#  10  capital_gain            32537 non-null  int64
#  11  capital_loss            32537 non-null  int64
#  12  hours_per_week          32537 non-null  int64
#  13  native_country          32537 non-null  object
#  14  salary                  32537 non-null  object
#  15  education_summary       32537 non-null  object
#  16  marital_status_summary  32537 non-null  object
#  17  native_country_summary  32537 non-null  object
# dtypes: float64(1), int64(5), object(12)
# memory usage: 5.7+ MB

# %%
# Drop the columns of "education", "education_num", "relationship", "marital_status", "native_country" permanently

# Your Code is Here
df.drop(['education', 'education_num', 'relationship', 'marital_status', 'native_country'], axis=1, inplace=True)

# %% [markdown]
# <a id="7"></a>
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;">Handling with Missing Value</p>
#
# <a href="#content" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# **Check the missing values for all features basically**

# %%
# Your Code is Here
df.isna().sum()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# gender                    0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %% [raw]
# Desired Output:
#
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# gender                    0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %% [markdown]
# **1. It seems that there is no missing value. But we know that "workclass", and "occupation" features have missing values as the "Unknown" string values. Examine these features in more detail.**
#
# **2. Decide if drop these "Unknown" string values or not**

# %%
# Your Code is Here

df["workclass"].value_counts()
# Out:
# workclass
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# Unknown              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# Unknown              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
# Your Code is Here

df["occupation"].value_counts()
# Out:
# occupation
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# Unknown              1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# Unknown              1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
# Your Code is Here

df[(df["workclass"]=="Unknown") | (df["workclass"]=="Never-worked" )]["workclass"].value_counts()
# Out:
# workclass
# Unknown         1836
# Never-worked       7
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# Unknown         1836
# Never-worked       7
# Name: workclass, dtype: int64

# %%
# Replace "Unknown" values with NaN using numpy library

# Your Code is Here

df.replace("Unknown", np.nan, inplace=True)

# %%
# Your Code is Here
df.isna().sum()
# Out:
# age                          0
# workclass                 1836
# fnlwgt                       0
# occupation                1843
# race                         0
# gender                       0
# capital_gain                 0
# capital_loss                 0
# hours_per_week               0
# salary                       0
# education_summary            0
# marital_status_summary       0
# native_country_summary       0
# dtype: int64

# %% [raw]
# Desired Output:
#
# age                          0
# workclass                 1836
# fnlwgt                       0
# occupation                1843
# race                         0
# gender                       0
# capital_gain                 0
# capital_loss                 0
# hours_per_week               0
# salary                       0
# education_summary            0
# marital_status_summary       0
# native_country_summary       0
# dtype: int64

# %%
# Drop missing values in df permanently

# Your Code is Here
df.dropna(inplace=True)

# %%
# Your Code is Here
df.isna().sum()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# gender                    0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %% [raw]
# Desired Output:
#
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# gender                    0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %%
# Your Code is Here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30694 entries, 0 to 32536
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     30694 non-null  int64
#  1   workclass               30694 non-null  object
#  2   fnlwgt                  30694 non-null  int64
#  3   occupation              30694 non-null  object
#  4   race                    30694 non-null  object
#  5   gender                  30694 non-null  object
#  6   capital_gain            30694 non-null  int64
#  7   capital_loss            30694 non-null  int64
#  8   hours_per_week          30694 non-null  int64
#  9   salary                  30694 non-null  object
#  10  education_summary       30694 non-null  object
#  11  marital_status_summary  30694 non-null  object
#  12  native_country_summary  30694 non-null  object
# dtypes: int64(5), object(8)
# memory usage: 3.3+ MB

# %% [raw]
# Desired Output:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30694 entries, 0 to 32560
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     30694 non-null  int64
#  1   workclass               30694 non-null  object
#  2   fnlwgt                  30694 non-null  int64
#  3   occupation              30694 non-null  object
#  4   race                    30694 non-null  object
#  5   gender                  30694 non-null  object
#  6   capital_gain            30694 non-null  int64
#  7   capital_loss            30694 non-null  int64
#  8   hours_per_week          30694 non-null  int64
#  9   salary                  30694 non-null  object
#  10  education_summary       30694 non-null  object
#  11  marital_status_summary  30694 non-null  object
#  12  native_country_summary  30694 non-null  object
# dtypes: int64(5), object(8)
# memory usage: 3.3+ MB

# %% [markdown]
# <a id="8"></a>
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;">Handling with Outliers</p>
#
# <a href="#content" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## Analyzing all Features  and Detecting Extreme Values

# %% [markdown]
# ### Boxplot and Histplot for all numeric features
#
# **Plot boxplots for each numeric features at the same figure as subplots**

# %%
# Set the figure size
plt.figure(figsize=(6, 4))

# Plot boxplots for each numeric feature
sns.boxplot(data=df.select_dtypes(include=['int64', 'float64']),palette="tab10", fill=False,)


# Show the plot
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/DKMSBDk/94.png)

# %%
numeric_features = df.select_dtypes(include=['int64', 'float64']).columns

# Calculate the number of rows and columns needed
num_cols = 3
num_rows = len(numeric_features) // num_cols + (len(numeric_features) % num_cols > 0)

# Set up the subplot grid
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(15, 8))

# Flatten the axes array to access each subplot
axes = axes.flatten()

# Plot boxplots for each numeric feature
for i, feature in enumerate(numeric_features):
    sns.boxplot(x=df[feature], ax=axes[i])
    #axes[i].set_title(feature)
fig.delaxes(axes[5])
# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/JKtcs9S/95.png)

# %% [markdown]
# **Plot both boxplots and histograms for each numeric features at the same figure as subplots**

# %%
# Your Code is Here
numeric_features = df.select_dtypes(include=['int64', 'float64']).columns

# Calculate the number of rows and columns needed
num_cols = 2
num_rows = len(numeric_features) 

# Set up the subplot grid
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(7, 15))
#for boxplots    
for i, feature in enumerate(numeric_features):       
    sns.boxplot(x=df[feature], ax=axes[i,0])
#for histplots    
for i, feature in enumerate(numeric_features):       
    sns.histplot(x=df[feature], ax=axes[i,1])      
       

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/fMpP3yR/96.png)

# %% [markdown]
# **Check the statistical values for all numeric features**

# %%
# Your Code is Here
df.select_dtypes(include=['int64', 'float64']).describe().T
# Out:
#                    count       mean        std       min        25%  \
# age            30694.000     38.448     13.115    17.000     28.000
# fnlwgt         30694.000 189848.229 105465.126 13769.000 117828.500
# capital_gain   30694.000   1106.902   7500.730     0.000      0.000
# capital_loss   30694.000     88.980    405.808     0.000      0.000
# hours_per_week 30694.000     40.953     11.984     1.000     40.000
#
#                       50%        75%         max
# age                37.000     47.000      90.000
# fnlwgt         178513.500 237293.750 1484705.000
# capital_gain        0.000      0.000   99999.000
# capital_loss        0.000      0.000    4356.000
# hours_per_week     40.000     45.000      99.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/t3MJHDr/97.png)

# %% [markdown]
# **1. After analyzing all features, we have decided that we can't evaluate extreme values in "fnlwgt, capital_gain, capital_loss" features in the scope of outliers.**
#
# **2. So let's examine "age and hours_per_week" features and detect extreme values which could be outliers by using IQR Rule.**

# %% [markdown]
# ### age

# %%
# Your Code is Here

# Your Code is Here
features = df["age"]

# Calculate the number of rows and columns needed
num_cols = 2
num_rows = 1

# Set up the subplot grid
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(6, 4))
#for boxplots    
      
sns.boxplot(y=features, ax=axes[0])
#for histplots    
     
sns.histplot(x=features, ax=axes[1])      
       

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/SnzH5Nz/98.png)

# %%
# Find IQR defining quantile 0.25 for low level and 0.75 for high level 

# Your Code is Here

# Calculate the 0.25th quantile for low level
low_age_q1 = df['age'].quantile(0.25)

# Calculate the 0.75th quantile for high level
high_age_q3 = df['age'].quantile(0.75)

# Calculate the interquartile range (IQR)
IQR_age = high_age_q3 - low_age_q1

# Display the result
print((low_age_q1, high_age_q3, IQR_age))
# Out:
# (28.0, 47.0, 19.0)

# %% [raw]
# Desired Output:
#
# (28.0, 47.0, 19.0)

# %%
# Find lower and upper limit using IQR

# Your Code is Here
lower_limit_age,upper_limit_age  = low_age_q1 - 1.5 * IQR_age, high_age_q3 + 1.5 * IQR_age

lower_limit_age,upper_limit_age
# Out:
# (-0.5, 75.5)

# %% [raw]
# Desired Output:
#
# (-0.5, 75.5)

# %%
# Your Code is Here
df[ (df["age"] > upper_limit_age)]["age"].value_counts()
# Out:
# age
# 76    30
# 77    20
# 80    16
# 79    15
# 78    14
# Name: count, dtype: int64

# %%
# Out:
# 75.5

# %% [raw]
# Desired Output:
#
# 90    35
# 76    30
# 77    20
# 80    16
# 79    15
# 81    14
# 78    14
# 84     8
# 82     7
# 83     5
# 88     3
# 85     3
# 86     1
# Name: age, dtype: int64

# %%
# Define the observations whose age is greater than upper limit and sort these observations by age in descending order
upper_age = df[ (df["age"] > upper_limit)]
# Your Code is Here

upper_age.sort_values(by="age", ascending=False)
# Out:
#        age         workclass  fnlwgt       occupation                race  \
# 8804    90           Private   87372   Prof-specialty               White
# 14154   90         Local-gov  187749     Adm-clerical  Asian-Pac-Islander
# 28445   90       Federal-gov  195433     Craft-repair               White
# 12971   90           Private  250832  Exec-managerial               White
# 11992   90           Private   40388  Exec-managerial               White
# ...    ...               ...     ...              ...                 ...
# 15096   76         Local-gov  169133     Adm-clerical               White
# 19076   76           Private  125784  Exec-managerial               White
# 23500   76           Private  142535     Adm-clerical               White
# 8238    76  Self-emp-not-inc  225964            Sales               White
# 23339   76           Private  199949     Adm-clerical               White
#
#        gender  capital_gain  capital_loss  hours_per_week salary  \
# 8804     Male         20051             0              72   >50K
# 14154    Male             0             0              20  <=50K
# 28445    Male             0             0              30  <=50K
# 12971    Male             0             0              40  <=50K
# 11992    Male             0             0              55  <=50K
# ...       ...           ...           ...             ...    ...
# 15096  Female             0             0              30  <=50K
# 19076    Male             0             0              40  <=50K
# 23500    Male             0             0               6  <=50K
# 8238     Male             0             0               8  <=50K
# 23339    Male         20051             0              50   >50K
#
#         education_summary marital_status_summary native_country_summary
# 8804     high_level_grade                married                     US
# 14154  medium_level_grade                married                 Others
# 28445  medium_level_grade                married                     US
# 12971     low_level_grade                married                     US
# 11992    high_level_grade              unmarried                     US
# ...                   ...                    ...                    ...
# 15096  medium_level_grade              unmarried                     US
# 19076    high_level_grade                married                     US
# 23500  medium_level_grade              unmarried                     US
# 8238   medium_level_grade              unmarried                     US
# 23339    high_level_grade                married                     US
#
# [171 rows x 13 columns]

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/x2wDgzQ/99.png)

# %% [markdown]
# ### hours_per_week

# %%
# Your Code is Here

features = df["hours_per_week"]

# Calculate the number of rows and columns needed
num_cols = 2
num_rows = 1

# Set up the subplot grid
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(7, 4))
#for boxplots    
      
sns.boxplot(y=features, ax=axes[0])
#for histplots    
     
sns.histplot(x=features, ax=axes[1],bins=10)      
       

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/xq53X6w/100.png)

# %%
# Find IQR defining quantile 0.25 for low level and 0.75 for high level 

# Your Code is Here


# Calculate the 0.25th quantile for low level
low_hour_q1 = df['hours_per_week'].quantile(0.25)

# Calculate the 0.75th quantile for high level
high_hour_q3 = df['hours_per_week'].quantile(0.75)

# Calculate the interquartile range (IQR)
IQR_hours = high_hour_q3 - low_hour_q1

# Display the result
print((low_hour_q1, high_hour_q3, IQR_hours))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hours_per_week'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1079], line 7
#       1 # Find IQR defining quantile 0.25 for low level and 0.75 for high level
#       2
#       3 # Your Code is Here
#       4
#       5
#       6 # Calculate the 0.25th quantile for low level
# ----> 7 low_hour_q1 = df['hours_per_week'].quantile(0.25)
#       9 # Calculate the 0.75th quantile for high level
#      10 high_hour_q3 = df['hours_per_week'].quantile(0.75)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'hours_per_week'

# %% [raw]
# Desired Output:
#
# (40.0, 45.0, 5.0)

# %%
# Find the lower and upper limit using IQR

# Your Code is Here
lower_limit_hours,upper_limit_hours  = low_level_q1 - 1.5 * IQR, high_level_q3 + 1.5 * IQR

lower_limit_hours,upper_limit_hours
# Out:
# (32.5, 52.5)

# %% [raw]
# Desired Output:
#
# (32.5, 52.5)

# %%
# Your Code is Here

df[ (df["hours_per_week"] > upper_limit)]["hours_per_week"].value_counts().sort_index(ascending=False)
# Out:
# hours_per_week
# 99      80
# 98      11
# 97       2
# 96       5
# 95       2
# 94       1
# 92       1
# 91       3
# 90      28
# 89       2
# 88       2
# 87       1
# 86       2
# 85      13
# 84      41
# 82       1
# 81       3
# 80     124
# 78       8
# 77       6
# 76       3
# 75      63
# 74       1
# 73       2
# 72      68
# 70     284
# 68      12
# 67       4
# 66      17
# 65     242
# 64      14
# 63      10
# 62      18
# 61       2
# 60    1441
# 59       5
# 58      27
# 57      17
# 56      91
# 55     683
# 54      39
# 53      23
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# 99      80
# 98      11
# 97       2
# 96       5
# 95       2
# 94       1
# 92       1
# 91       3
# 90      28
# 89       2
# 88       2
# 87       1
# 86       2
# 85      13
# 84      41
# 82       1
# 81       3
# 80     124
# 78       8
# 77       6
# 76       3
# 75      63
# 74       1
# 73       2
# 72      68
# 70     284
# 68      12
# 67       4
# 66      17
# 65     242
# 64      14
# 63      10
# 62      18
# 61       2
# 60    1441
# 59       5
# 58      27
# 57      17
# 56      91
# 55     683
# 54      39
# 53      23
# Name: hours_per_week, dtype: int64

# %%
# Define the observations where  hours per week are greater than upper limit and 
# sort these observations by hours per week in descending order

# Your Code is Here
upper_hour = df[ (df["hours_per_week"] > upper_limit)]
# Your Code is Here

upper_hour.sort_values(by="hours_per_week", ascending=False)
# Out:
#        age         workclass  fnlwgt        occupation   race  gender  \
# 25970   44         Local-gov  212665   Protective-serv  Black    Male
# 19520   38           Private   66326  Transport-moving  White    Male
# 8794    39           Private   70995  Transport-moving  White    Male
# 15528   29           Private  167716     Other-service  White  Female
# 22300   26  Self-emp-not-inc  258306   Farming-fishing  White    Male
# ...    ...               ...     ...               ...    ...     ...
# 1138    27           Private  138705      Craft-repair  White    Male
# 23229   58           Private  248739   Farming-fishing  White    Male
# 28838   62           Private  123411  Transport-moving  White    Male
# 18410   24           Private  117167     Other-service  White  Female
# 31600   61  Self-emp-not-inc  268831             Sales  White    Male
#
#        capital_gain  capital_loss  hours_per_week salary   education_summary  \
# 25970             0             0              99  <=50K  medium_level_grade
# 19520             0             0              99  <=50K  medium_level_grade
# 8794          15024             0              99   >50K    high_level_grade
# 15528             0             0              99  <=50K  medium_level_grade
# 22300             0             0              99  <=50K     low_level_grade
# ...             ...           ...             ...    ...                 ...
# 1138              0             0              53  <=50K  medium_level_grade
# 23229             0             0              53   >50K  medium_level_grade
# 28838             0             0              53  <=50K     low_level_grade
# 18410             0             0              53  <=50K  medium_level_grade
# 31600             0             0              53  <=50K  medium_level_grade
#
#       marital_status_summary native_country_summary
# 25970                married                     US
# 19520                married                     US
# 8794                 married                     US
# 15528              unmarried                     US
# 22300                married                     US
# ...                      ...                    ...
# 1138                 married                     US
# 23229                married                     US
# 28838                married                     US
# 18410              unmarried                     US
# 31600                married                     US
#
# [3402 rows x 13 columns]

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/zGCnbjz/101.png)

# %%
# Your Code is Here

.value_counts().sort_index()
# Out:
# hours_per_week
# 1        8
# 2       15
# 3       24
# 4       28
# 5       39
# 6       40
# 7       20
# 8      103
# 9       17
# 10     223
# 11       9
# 12     143
# 13      19
# 14      28
# 15     350
# 16     182
# 17      27
# 18      64
# 19      14
# 20    1066
# 21      23
# 22      39
# 23      20
# 24     220
# 25     582
# 26      30
# 27      28
# 28      74
# 29       6
# 30    1009
# 31       5
# 32     239
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# 1        8
# 2       15
# 3       24
# 4       28
# 5       39
# 6       40
# 7       20
# 8      103
# 9       17
# 10     223
# 11       9
# 12     143
# 13      19
# 14      28
# 15     350
# 16     182
# 17      27
# 18      64
# 19      14
# 20    1066
# 21      23
# 22      39
# 23      20
# 24     220
# 25     582
# 26      30
# 27      28
# 28      74
# 29       6
# 30    1009
# 31       5
# 32     239
# Name: hours_per_week, dtype: int64

# %%
# Your Code is Here
df[(df["hours_per_week"] < lower_limit)].groupby("salary")["hours_per_week"].describe()
# Out:
#           count   mean   std   min    25%    50%    75%    max
# salary
# <=50K  4342.000 21.584 7.328 1.000 16.000 20.000 30.000 32.000
# >50K    320.000 22.038 7.825 1.000 18.000 24.000 30.000 32.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/swYNtdM/102.png)

# %%
# Your Code is Here
df[(df["age"] > upper_limit)].groupby("salary")["age"].describe()
# Out:
#           count   mean   std    min    25%    50%    75%    max
# salary
# <=50K  3139.000 60.458 6.046 53.000 56.000 59.000 64.000 80.000
# >50K   1528.000 58.863 5.311 53.000 55.000 58.000 61.000 80.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/S7RWpxD/103.png)

# %% [markdown]
# **Result :** As we see, there are number of extreme values in both "age and hours_per_week" features. But how can we know if these extreme values are outliers or not? At this point, **domain knowledge** comes to the fore.
#
# **Domain Knowledge for this dataset:**
# 1. In this dataset, all values are created according to the statements of individuals. So It can be some "data entries errors".
# 2. In addition, we have aimed to create an ML model with some restrictions as getting better performance from the ML model.
# 3. In this respect, our sample space ranges for some features are as follows.
#     - **age : 17 to 80**
#     - **hours_per_week : 7 to 70**
#     - **if somebody's age is more than 60, he/she can't work more than 60 hours in a week**

# %% [markdown]
# ### Dropping rows according to the domain knownledge

# %%
# Create a condition according to your domain knowledge on age stated above and 
# sort the observations meeting this condition by age in ascending order
df_remove = df.loc[(df["age"]>80) ].sort_values(by="age",ascending=False)
# Your Code is Here
df_remove
# Out:
#        age         workclass  fnlwgt         occupation                race  \
# 222     90           Private   51744      Other-service               Black
# 18823   90           Private  115306    Exec-managerial               White
# 10542   90           Private  175491       Craft-repair               White
# 11509   90           Private   87285      Other-service               White
# 11992   90           Private   40388    Exec-managerial               White
# 12971   90           Private  250832    Exec-managerial               White
# 14154   90         Local-gov  187749       Adm-clerical  Asian-Pac-Islander
# 15886   90           Private   88991    Exec-managerial               White
# 18270   90           Private  311184              Sales               White
# 18406   90           Private  313749     Prof-specialty               White
# 18716   90         Local-gov  153602      Other-service               White
# 19203   90           Private  139660              Sales               Black
# 8971    90           Private   46786              Sales               White
# 19480   90           Private   84553  Machine-op-inspct               White
# 19738   90           Private  226968  Machine-op-inspct               White
# 20601   90           Private  206667     Prof-specialty               White
# 22208   90           Private   52386     Prof-specialty  Asian-Pac-Islander
# 24028   90  Self-emp-not-inc   82628    Exec-managerial               White
# 28445   90       Federal-gov  195433       Craft-repair               White
# 31008   90           Private   47929  Machine-op-inspct               White
# 32254   90           Private  313749       Adm-clerical               White
# 32344   90         Local-gov  214594    Protective-serv               White
# 10207   90  Self-emp-not-inc  282095    Farming-fishing               White
# 15350   90           Private   90523   Transport-moving               White
# 5368    90         Local-gov  227796    Exec-managerial               White
# 4070    90           Private  313986  Handlers-cleaners               White
# 1040    90           Private  137018      Other-service               White
# 6230    90  Self-emp-not-inc  155981     Prof-specialty               White
# 1935    90           Private  221832    Exec-managerial               White
# 2303    90           Private   52386      Other-service  Asian-Pac-Islander
# 5270    90           Private  141758       Adm-clerical               White
# 6622    90           Private  313986       Craft-repair               White
# 2891    90           Private  171956       Adm-clerical               White
# 5404    90           Private   51744    Exec-managerial               Black
# 8804    90           Private   87372     Prof-specialty               White
# 1168    88  Self-emp-not-inc  206291     Prof-specialty               White
# 22880   88           Private   68539       Adm-clerical               White
# 21824   88  Self-emp-not-inc  187097    Exec-managerial               White
# 24012   86           Private  149912       Adm-clerical               White
# 20454   85  Self-emp-not-inc  166027              Sales               White
# 8379    85           Private  115364              Sales               White
# 32435   85           Private   98611    Exec-managerial               White
# 26714   84           Private  188328     Prof-specialty               White
# 27778   84           Private  388384     Prof-specialty               Black
# 9468    84         Local-gov  163685    Exec-managerial               White
# 6212    84  Self-emp-not-inc  155057    Farming-fishing               White
# 14706   84         Local-gov  135839       Adm-clerical               White
# 11235   84      Self-emp-inc  172907              Sales               White
# 7718    84           Private  241065     Prof-specialty               White
# 15656   84           Private  132806      Other-service               White
# 7479    83           Private  195507    Protective-serv               White
# 24380   83      Self-emp-inc  153183    Exec-managerial               White
# 23444   83      Self-emp-inc  240150    Farming-fishing               White
# 19163   83      Self-emp-inc  272248              Sales               White
# 16296   83  Self-emp-not-inc  213866    Exec-managerial               White
# 14751   82           Private  132870    Exec-managerial               White
# 8429    82           Private  152148  Handlers-cleaners               White
# 20412   82           Private  147729      Other-service               White
# 22467   82      Self-emp-inc  120408              Sales               White
# 31833   82  Self-emp-not-inc   71438    Farming-fishing               White
# 13691   82  Self-emp-not-inc  240491       Craft-repair               White
# 24265   82      Self-emp-inc  130329    Farming-fishing               White
# 4834    81           Private  364099       Adm-clerical               White
# 29573   81  Self-emp-not-inc  193237              Sales               White
# 28928   81           Private  129338   Transport-moving               White
# 12826   81           Private  201398     Prof-specialty               White
# 918     81  Self-emp-not-inc  136063    Exec-managerial               White
# 13290   81           Private  100675     Prof-specialty               White
# 24545   81           Private   98116              Sales               White
# 3537    81  Self-emp-not-inc  137018       Adm-clerical               White
# 13923   81  Self-emp-not-inc  123959     Prof-specialty               White
# 19036   81         State-gov  132204      Other-service               White
# 6746    81           Private  122651              Sales               White
# 2906    81           Private  114670    Priv-house-serv               Black
# 21490   81           Private  177408    Exec-managerial               White
# 19486   81      Self-emp-inc  247232    Exec-managerial               White
#
#        gender  capital_gain  capital_loss  hours_per_week salary  \
# 222      Male             0          2206              40  <=50K
# 18823  Female             0             0              40  <=50K
# 10542    Male          9386             0              50   >50K
# 11509  Female             0             0              24  <=50K
# 11992    Male             0             0              55  <=50K
# 12971    Male             0             0              40  <=50K
# 14154    Male             0             0              20  <=50K
# 15886  Female             0             0              40   >50K
# 18270    Male             0             0              20  <=50K
# 18406  Female             0             0              10  <=50K
# 18716    Male          6767             0              40  <=50K
# 19203  Female             0             0              37  <=50K
# 8971     Male          9386             0              15   >50K
# 19480    Male             0             0              40  <=50K
# 19738    Male             0             0              40  <=50K
# 20601  Female             0             0              40   >50K
# 22208    Male             0             0              40  <=50K
# 24028    Male          2964             0              12  <=50K
# 28445    Male             0             0              30  <=50K
# 31008    Male             0             0              40  <=50K
# 32254  Female             0             0              25  <=50K
# 32344    Male          2653             0              40  <=50K
# 10207    Male             0             0              40  <=50K
# 15350    Male             0             0              99  <=50K
# 5368     Male         20051             0              60   >50K
# 4070     Male             0             0              40  <=50K
# 1040   Female             0             0              40  <=50K
# 6230     Male         10566             0              50  <=50K
# 1935     Male             0             0              45  <=50K
# 2303     Male             0             0              35  <=50K
# 5270   Female             0             0              40  <=50K
# 6622     Male             0             0              40  <=50K
# 2891   Female             0             0              40  <=50K
# 5404     Male             0             0              50   >50K
# 8804     Male         20051             0              72   >50K
# 1168     Male             0             0              40  <=50K
# 22880  Female             0             0              40  <=50K
# 21824    Male             0             0              40  <=50K
# 24012  Female             0             0              40  <=50K
# 20454  Female             0             0              50  <=50K
# 8379     Male             0             0              35  <=50K
# 32435    Male             0             0               3  <=50K
# 26714  Female             0             0              16  <=50K
# 27778    Male             0             0              10  <=50K
# 9468   Female             0             0              33  <=50K
# 6212     Male             0             0              20  <=50K
# 14706  Female             0             0              14  <=50K
# 11235    Male             0             0              35   >50K
# 7718     Male             0             0              66  <=50K
# 15656  Female             0             0              13  <=50K
# 7479     Male             0             0              55  <=50K
# 24380    Male             0          2392              55   >50K
# 23444    Male         20051             0              50   >50K
# 19163    Male             0             0              20  <=50K
# 16296    Male             0             0               8  <=50K
# 14751  Female             0          4356              18  <=50K
# 8429     Male             0             0               2  <=50K
# 20412    Male             0             0              20  <=50K
# 22467    Male             0             0              20  <=50K
# 31833    Male             0             0              20  <=50K
# 13691    Male             0             0              40  <=50K
# 24265    Male             0             0              50  <=50K
# 4834   Female             0             0              20  <=50K
# 29573    Male             0             0              45  <=50K
# 28928    Male             0             0              10  <=50K
# 12826    Male             0             0              60  <=50K
# 918      Male             0             0              30  <=50K
# 13290    Male             0             0              15  <=50K
# 24545    Male             0             0              50   >50K
# 3537   Female             0             0              20  <=50K
# 13923  Female             0          1668               3  <=50K
# 19036  Female             0             0              20  <=50K
# 6746     Male             0             0              15  <=50K
# 2906   Female          2062             0               5  <=50K
# 21490    Male             0          2377              26   >50K
# 19486  Female          2936             0              28  <=50K
#
#         education_summary marital_status_summary native_country_summary
# 222    medium_level_grade              unmarried                     US
# 18823    high_level_grade              unmarried                     US
# 10542  medium_level_grade                married                 Others
# 11509  medium_level_grade              unmarried                     US
# 11992    high_level_grade              unmarried                     US
# 12971     low_level_grade                married                     US
# 14154  medium_level_grade                married                 Others
# 15886    high_level_grade                married                 Others
# 18270    high_level_grade                married                 Others
# 18406    high_level_grade              unmarried                     US
# 18716  medium_level_grade                married                     US
# 19203  medium_level_grade              unmarried                     US
# 8971     high_level_grade                married                     US
# 19480  medium_level_grade                married                     US
# 19738     low_level_grade                married                     US
# 20601    high_level_grade                married                     US
# 22208    high_level_grade              unmarried                     US
# 24028  medium_level_grade              unmarried                     US
# 28445  medium_level_grade                married                     US
# 31008  medium_level_grade                married                     US
# 32254  medium_level_grade              unmarried                     US
# 32344     low_level_grade                married                     US
# 10207  medium_level_grade                married                     US
# 15350  medium_level_grade              unmarried                     US
# 5368     high_level_grade                married                     US
# 4070      low_level_grade              unmarried                     US
# 1040   medium_level_grade              unmarried                     US
# 6230     high_level_grade                married                     US
# 1935     high_level_grade                married                     US
# 2303   medium_level_grade              unmarried                     US
# 5270      low_level_grade              unmarried                     US
# 6622      low_level_grade                married                     US
# 2891   medium_level_grade              unmarried                 Others
# 5404     high_level_grade              unmarried                     US
# 8804     high_level_grade                married                     US
# 1168     high_level_grade                married                     US
# 22880  medium_level_grade              unmarried                     US
# 21824    high_level_grade                married                     US
# 24012    high_level_grade              unmarried                     US
# 20454  medium_level_grade              unmarried                     US
# 8379   medium_level_grade              unmarried                     US
# 32435    high_level_grade                married                 Others
# 26714  medium_level_grade              unmarried                     US
# 27778     low_level_grade                married                     US
# 9468   medium_level_grade              unmarried                     US
# 6212     high_level_grade                married                     US
# 14706  medium_level_grade              unmarried                     US
# 11235  medium_level_grade                married                     US
# 7718     high_level_grade              unmarried                     US
# 15656  medium_level_grade              unmarried                     US
# 7479   medium_level_grade              unmarried                     US
# 24380    high_level_grade                married                     US
# 23444     low_level_grade                married                     US
# 19163  medium_level_grade              unmarried                     US
# 16296  medium_level_grade              unmarried                     US
# 14751  medium_level_grade              unmarried                     US
# 8429      low_level_grade                married                     US
# 20412     low_level_grade              unmarried                     US
# 22467  medium_level_grade              unmarried                     US
# 31833  medium_level_grade                married                     US
# 13691  medium_level_grade                married                 Others
# 24265     low_level_grade                married                     US
# 4834   medium_level_grade              unmarried                     US
# 29573     low_level_grade              unmarried                 Others
# 28928     low_level_grade                married                     US
# 12826    high_level_grade              unmarried                 Others
# 918    medium_level_grade                married                     US
# 13290     low_level_grade                married                 Others
# 24545    high_level_grade              unmarried                     US
# 3537   medium_level_grade              unmarried                     US
# 13923    high_level_grade              unmarried                 Others
# 19036     low_level_grade              unmarried                     US
# 6746   medium_level_grade                married                     US
# 2906      low_level_grade              unmarried                     US
# 21490  medium_level_grade                married                     US
# 19486     low_level_grade                married                     US

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/pJC50ZV/104.png)

# %%
# Find the shape of the dataframe created by the condition defined above for age 

# Your Code is Here
df_remove.shape
# Out:
# (76, 13)

# %% [raw]
# Desired Output:
#
# (76, 13)

# %%
# Assign the indices of the rows defined in accordance with condition above for age
remove_index = df_remove.index
# Your Code is Here
remove_index
# Out:
# Index([  222, 18823, 10542, 11509, 11992, 12971, 14154, 15886, 18270, 18406,
#        18716, 19203,  8971, 19480, 19738, 20601, 22208, 24028, 28445, 31008,
#        32254, 32344, 10207, 15350,  5368,  4070,  1040,  6230,  1935,  2303,
#         5270,  6622,  2891,  5404,  8804,  1168, 22880, 21824, 24012, 20454,
#         8379, 32435, 26714, 27778,  9468,  6212, 14706, 11235,  7718, 15656,
#         7479, 24380, 23444, 19163, 16296, 14751,  8429, 20412, 22467, 31833,
#        13691, 24265,  4834, 29573, 28928, 12826,   918, 13290, 24545,  3537,
#        13923, 19036,  6746,  2906, 21490, 19486],
#       dtype='int64')

# %% [raw]
# Desired Output:
#
# Int64Index([  222, 18832, 10545, 11512, 11996, 12975, 14159, 15892, 18277,
#             18413, 18725, 19212,  8973, 19489, 19747, 20610, 22220, 24043,
#             28463, 31030, 32277, 32367, 10210, 15356,  5370,  4070,  1040,
#              6232,  1935,  2303,  5272,  6624,  2891,  5406,  8806,  1168,
#             22895, 21835, 24027, 20463,  8381, 32459, 26731, 27795,  9471,
#              6214, 14711, 11238,  7720, 15662,  7481, 24395, 23459, 19172,
#             16302, 14756,  8431, 20421, 22481, 31855, 13696, 24280,  4834,
#             29594, 28948, 12830,   918, 13295, 24560,  3537, 13928, 19045,
#              6748,  2906, 21501, 19495],
#            dtype='int64')

# %%
# Drop these indices defined above for age
df.drop(remove_index, inplace=True)
# Your Code is Here

# %%
# Create a condition according to your domain knowledge on hours per week stated above and 
# sort the observations meeting this condition by hours per week in descending order

# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/rMp7C58/105.png)

# %%
# Find the shape of the dataframe created by the condition defined above for hours per week 

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (621, 13)

# %%
# Assign the indices of the rows defined in accordance with condition above for hours per week

# Your Code is Here

# %% [raw]
# Desired Output:
#
# Int64Index([22216,  5432, 19053, 19141, 19399, 19529, 19731, 19997, 20036,
#             21056,
#             ...
#              6180, 29867,  1036, 11451, 22960, 20909, 25078, 19750,   189,
#             24284],
#            dtype='int64', length=621)

# %%
# Drop these indices defined above for hours per week

# Your Code is Here

# %%
# Create a condition according to your domain knowledge on both age and hours per week stated above 

# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Ch8XSdW/106.png)

# %%
# Find the shape of the dataframe created by the condition defined above for both age and hours per week


# Your Code is Here

# %% [raw]
# Desired Output:
#
# (23, 13)

# %%
# Assign the indices of the rows defined in accordance with condition above for both age and hours per week

# Your Code is Here

# %% [raw]
# Desired Output:
#
# Int64Index([ 1541,  2154,  2184,  2665,  3101,  5417,  6826,  8066,  9646,
#             12624, 16634, 18367, 19584, 20125, 23399, 23585, 24903, 25910,
#             26625, 27721, 28294, 31342, 32192],
#            dtype='int64')

# %%
# Drop these indices defined above for both age and hours per week

# Your Code is Here

# %%
# What is new shape of dataframe now

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (29974, 13)

# %%
# Reset the indices and take the head of DataFrame now

# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/5MXPD2b/107.png)

# %% [markdown]
# <a id="9"></a>
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;">Final Step to Make the Dataset Ready for ML Models</p>
#
# <a href="#content" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## Final Step
# - Convert all features to numeric
# - Take a look at correlation between features by utilizing power of visualizing

# %% [markdown]
# ### Convert all features to numeric

# %% [markdown]
# **Convert target feature (salary) to numeric (0 and 1) by using map function**

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 29969    0
# 29970    1
# 29971    0
# 29972    0
# 29973    1
# Name: salary, Length: 29974, dtype: int64

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# 0    22524
# 1     7450
# Name: salary, dtype: int64

# %% [markdown]
# **Convert all features to numeric by using get_dummies function**

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/0F1SHRt/108.png)

# %%
# What's the shape of dataframe

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (29974, 13)

# %%
# What's the shape of dataframe created by dummy operation

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (29974, 34)

# %% [markdown]
# ### Take a look at correlation between features by utilizing power of visualizing

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Dgb8RYZ/109.png)

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/5XH3X4q/110.png)

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/19RytkS/111.png)

# %%
# Your Code is Here

# %% [markdown]
# ![image.png](https://i.ibb.co/80GcYKr/112.png)

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/0MCPc4d/113.png)

# %% [markdown]
# <a id="10"></a>
#
# <p style="background-color:romance; color:plum; font-size:220%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1; font-weight:bold;">The End of the Project</p>
#
# <p style="text-align: center; line-height: 1"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# <p style="background-color:romance; color:plum; font-size:150%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1; font-weight:bold;">WAY TO REINVENT YOURSELF</p>
#
# <a href="#content" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
